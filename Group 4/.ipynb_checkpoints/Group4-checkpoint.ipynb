# %%
# === Cell 1: clone NanoGPT & set paths ===
import os, json, sys
from pathlib import Path

# clone (skip if already cloned)
if not Path("nanoGPT").exists():
    # !git clone https://github.com/karpathy/nanoGPT.git

REPO_DIR = str(Path("nanoGPT").resolve())
OUT_DIR  = str(Path(REPO_DIR) / "out_onegroup")   # keep our runs separate
DATA_DIR = str(Path(REPO_DIR) / "data" / "shakespeare_char")  # we'll use Tiny Shakespeare

TRAIN_PY  = str(Path(REPO_DIR) / "train.py")
MODEL_PY  = str(Path(REPO_DIR) / "model.py")
SAMPLE_PY = str(Path(REPO_DIR) / "sample.py")

os.makedirs(OUT_DIR, exist_ok=True)

print("REPO_DIR:", REPO_DIR)
print("OUT_DIR :", OUT_DIR)
print("Files exist:", {
    "train.py": os.path.exists(TRAIN_PY),
    "model.py": os.path.exists(MODEL_PY),
    "sample.py": os.path.exists(SAMPLE_PY),
})
# Out:
# Cloning into 'nanoGPT'...
# remote: Enumerating objects: 686, done.
# remote: Total 686 (delta 0), reused 0 (delta 0), pack-reused 686 (from 1)
# Receiving objects: 100% (686/686), 974.06 KiB | 4.85 MiB/s, done.
# Resolving deltas: 100% (380/380), done.
# REPO_DIR: /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT
# OUT_DIR : /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/out_onegroup
# Files exist: {'train.py': True, 'model.py': True, 'sample.py': True}

# %%
# !python nanoGPT/data/shakespeare_char/prepare.py
# Out:
# length of dataset in characters: 1,115,394
# all the unique characters:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# vocab size: 65
# train has 1,003,854 tokens
# val has 111,540 tokens

# %%
# === Cell 2: prepare Tiny Shakespeare data ===
import os
from pathlib import Path

# run the repo's prepare script
# %cd "$REPO_DIR"
# !python data/shakespeare_char/prepare.py
# %cd - > /dev/null

# confirm files
data_files = list(Path(DATA_DIR).glob("*"))
print("DATA_DIR:", DATA_DIR)
for p in data_files:
    print(" -", p.name)
# Out:
# /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT
# length of dataset in characters: 1,115,394
# all the unique characters:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# vocab size: 65
# train has 1,003,854 tokens
# val has 111,540 tokens
# [Errno 2] No such file or directory: '- > /dev/null'
# /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT
# DATA_DIR: /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/data/shakespeare_char
#  - input.txt
#  - val.bin
#  - meta.pkl
#  - readme.md
#  - train.bin
#  - prepare.py

# %%
# === Cell 3: write single-group config_override.json ===
import json, os
from pathlib import Path

# A reasonable "one group" student config (small & quick)
cfg = {
    # architecture
    "block_size": 256,
    "n_layer": 6,
    "n_head": 8,
    "n_embd": 512,
    "dropout": 0.1,
    # training
    "batch_size": 8,
    "max_iters": 500,
    "learning_rate": 3e-4,
    "weight_decay": 1e-1,
    "beta1": 0.9,
    "beta2": 0.95,
    "grad_clip": 1.0,
    "decay_lr": True,
    "warmup_iters": 50,
    "lr_decay_iters": 500,
    "min_lr": 1e-5,
    # eval/checkpoint cadence
    "eval_interval": 50,
    "eval_iters": 100,
    "always_save_checkpoint": True,
    "eval_only": False,
    # I/O
    "out_dir": str(Path(REPO_DIR) / "out_group4"),
    "data_dir": DATA_DIR,
    # speed / debug
    "compile": False
}

ovr_path = str(Path(OUT_DIR) / "config_override.json")
with open(ovr_path, "w") as f:
    json.dump(cfg, f, indent=2)

print("Wrote override ->", ovr_path)
print(json.dumps(cfg, indent=2))
# Out:
# Wrote override -> /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/out_onegroup/config_override.json
# {
#   "block_size": 256,
#   "n_layer": 6,
#   "n_head": 8,
#   "n_embd": 512,
#   "dropout": 0.1,
#   "batch_size": 8,
#   "max_iters": 500,
#   "learning_rate": 0.0003,
#   "weight_decay": 0.1,
#   "beta1": 0.9,
#   "beta2": 0.95,
#   "grad_clip": 1.0,
#   "decay_lr": true,
#   "warmup_iters": 50,
#   "lr_decay_iters": 500,
#   "min_lr": 1e-05,
#   "eval_interval": 50,
#   "eval_iters": 100,
#   "always_save_checkpoint": true,
#   "eval_only": false,
#   "out_dir": "/home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/out_group4",
#   "data_dir": "/home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/data/shakespeare_char",
#   "compile": false
# }

# %%
# === Cell 4: patch train.py (idempotent) ===
from pathlib import Path
import re

tp = Path(TRAIN_PY).read_text()

# 1) Ensure it loads our override JSON early (affects out_dir, data_dir, etc.)
if "BEGIN: config override loader (onegroup)" not in tp:
    insert_after = tp.find("# -----------------------------------------------------------------------------\nconfig_keys")
    if insert_after == -1:
        insert_after = 0
    loader = f"""
# ==== BEGIN: config override loader (onegroup) ====
import json as _json
try:
    _OVR = r"{ovr_path}"
    if os.path.exists(_OVR):
        with open(_OVR, "r") as _f:
            _ovr = _json.load(_f)
        def _set(name, default=None):
            globals()[name] = _ovr.get(name, globals().get(name, default))
        # core
        _set("block_size")
        _set("n_layer"); _set("n_head"); _set("n_embd")
        _set("dropout")
        _set("batch_size"); _set("max_iters")
        # opt
        _set("learning_rate"); _set("weight_decay")
        _set("beta1"); _set("beta2")
        _set("grad_clip")
        _set("decay_lr"); _set("warmup_iters"); _set("lr_decay_iters"); _set("min_lr")
        # io
        _set("out_dir"); _set("eval_interval"); _set("eval_iters")
        _set("always_save_checkpoint"); _set("eval_only")
        _set("compile")
        # dataset resolution
        globals()["data_dir"] = _ovr.get("data_dir", os.path.join('data', globals().get("dataset","openwebtext")))
        print(f"[train.py] Loaded override from {{_OVR}}")
except Exception as _e:
    print("[train.py] Override load failed:", _e)
# ==== END: config override loader (onegroup) ====
"""
    tp = tp.replace("config = {k: globals()[k] for k in config_keys} # will be useful for logging",
                    "config = {k: globals()[k] for k in config_keys} # will be useful for logging\n" + loader)

# 2) Loss logger defined BEFORE training loop
if "BEGIN: loss logger (onegroup)" not in tp:
    loss_logger = """
# ==== BEGIN: loss logger (onegroup) ====
import csv as _csv
try:
    os.makedirs(out_dir, exist_ok=True)
except Exception:
    out_dir = "out"
    os.makedirs(out_dir, exist_ok=True)
_loss_csv = os.path.join(out_dir, "loss_log.csv")
if not os.path.exists(_loss_csv):
    with open(_loss_csv, "w", newline="") as _f:
        _w = _csv.writer(_f); _w.writerow(["iter","split","loss"])
def _append_loss_row(it, split, loss):
    try:
        with open(_loss_csv, "a", newline="") as _f:
            _w = _csv.writer(_f); _w.writerow([int(it), str(split), float(loss)])
    except Exception as _e:
        print("[warn] could not write loss log:", _e)
# ==== END: loss logger (onegroup) ====
"""
    # put it after the get_lr function (safe place)
    anchor = "def get_lr(it):"
    idx = tp.find(anchor)
    if idx != -1:
        end = tp.find("\n", idx)
        tp = tp[:end] + "\n" + loss_logger + tp[end:]
    else:
        tp = tp + "\n" + loss_logger

# 3) Log eval losses inside estimate_loss() before return
if "eval loss log (onegroup)" not in tp:
    tp = re.sub(
        r"(def\s+estimate_loss\s*\(\)\s*:\s*\n(?:.|\n)*?return\s+out)",
        r"""def estimate_loss():
    out = {}
    model.eval()
    for split in ['train','val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            with ctx:
                logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    # === eval loss log (onegroup) ===
    try:
        for _s, _v in out.items():
            _append_loss_row(iter_num, _s, float(_v))
    except Exception as _e:
        print("[warn] eval loss log failed:", _e)
    return out""",
        tp, count=1, flags=re.DOTALL
    )

# 4) Log train loss once per iteration where it prints the iter line
if "train loss log (onegroup)" not in tp:
    tp = tp.replace(
        "print(f\"iter {iter_num}: loss {lossf:.4f}, time {dt*1000:.2f}ms, mfu {running_mfu*100:.2f}%\")",
        "print(f\"iter {iter_num}: loss {lossf:.4f}, time {dt*1000:.2f}ms, mfu {running_mfu*100:.2f}%\")\n"
        "        try:\n"
        "            _append_loss_row(iter_num, 'train', float(lossf))\n"
        "        except Exception as _e:\n"
        "            print('[warn] train loss log failed:', _e)"
    )

# 5) Switch to new GradScaler API (silence deprecation)
tp = tp.replace("torch.cuda.amp.GradScaler(", "torch.amp.GradScaler('cuda', ")

Path(TRAIN_PY).write_text(tp)
print("train.py patched ✅")
# Out:
# train.py patched ✅

# %%
# === FIX train.py indentation + logger placement ===
from pathlib import Path
import re, textwrap

tp_path = Path(REPO_DIR) / "train.py"
txt = tp_path.read_text()

# 1. remove any previously inserted logger blocks that caused the indent error
txt = re.sub(r"# ==== BEGIN: loss logger.*?# ==== END: loss logger.*?====", "", txt, flags=re.S)

# 2. inject clean logger block near top (right after imports)
logger_block = textwrap.dedent("""
# ==== BEGIN: loss logger (onegroup fixed) ====
import csv as _csv, os
_loss_csv = os.path.join(out_dir, "loss_log.csv")
os.makedirs(out_dir, exist_ok=True)
if not os.path.exists(_loss_csv):
    with open(_loss_csv, "w", newline="") as _f:
        _csv.writer(_f).writerow(["iter","split","loss"])

def _append_loss_row(it, split, loss):
    try:
        with open(_loss_csv, "a", newline="") as _f:
            _csv.writer(_f).writerow([int(it), str(split), float(loss)])
    except Exception as _e:
        print("[warn] could not write loss log:", _e)
# ==== END: loss logger (onegroup fixed) ====
""")

# place it right after first import block
insert_at = txt.find("from model import GPTConfig, GPT")
if insert_at != -1:
    end = txt.find("\n", insert_at) + 1
    txt = txt[:end] + logger_block + txt[end:]
else:
    txt = logger_block + "\n" + txt

tp_path.write_text(txt)
print("✅ train.py fixed: logger inserted at top-level (no indentation error).")
# Out:
# ✅ train.py fixed: logger inserted at top-level (no indentation error).

# %%
# !head -n 300 "$REPO_DIR/train.py" | grep "loss logger"
# Out:
# # ==== BEGIN: loss logger (onegroup fixed) ====
# # ==== END: loss logger (onegroup fixed) ====

# %%
# === FIX: move logger below out_dir definition ===
from pathlib import Path
import re, textwrap

tp_path = Path(REPO_DIR) / "train.py"
txt = tp_path.read_text()

# Remove any prior inserted logger blocks
txt = re.sub(r"# ==== BEGIN: loss logger.*?# ==== END: loss logger.*?====", "", txt, flags=re.S)

# Build clean logger block (depends on out_dir)
logger_block = textwrap.dedent("""
# ==== BEGIN: loss logger (onegroup fixed, after out_dir) ====
import csv as _csv, os
_loss_csv = os.path.join(out_dir, "loss_log.csv")
os.makedirs(out_dir, exist_ok=True)
if not os.path.exists(_loss_csv):
    with open(_loss_csv, "w", newline="") as _f:
        _csv.writer(_f).writerow(["iter","split","loss"])

def _append_loss_row(it, split, loss):
    try:
        with open(_loss_csv, "a", newline="") as _f:
            _csv.writer(_f).writerow([int(it), str(split), float(loss)])
    except Exception as _e:
        print("[warn] could not write loss log:", _e)
# ==== END: loss logger (onegroup fixed, after out_dir) ====
""")

# Find insertion point: right after the first occurrence of "out_dir ="
idx = txt.find("out_dir =")
if idx == -1:
    raise RuntimeError("Could not find 'out_dir =' in train.py; please verify file.")
line_end = txt.find("\n", idx)
patched = txt[:line_end+1] + logger_block + txt[line_end+1:]

tp_path.write_text(patched)
print("✅ Logger moved below out_dir definition. Ready to train again.")
# Out:
# ✅ Logger moved below out_dir definition. Ready to train again.

# %%
# --- Patch train.py: stop overwriting data_dir to 'data/openwebtext' ---
from pathlib import Path
import re

tp_path = Path(REPO_DIR) / "train.py"
txt = tp_path.read_text()

# Replace the hard assignment:
#   data_dir = os.path.join('data', dataset)
# with a guarded version that respects an override:
patched = re.sub(
    r"\bdata_dir\s*=\s*os\.path\.join\('data',\s*dataset\)",
    "data_dir = globals().get('data_dir') or os.path.join('data', dataset)",
    txt,
    count=1
)

tp_path.write_text(patched)
print("Patched train.py to respect overridden data_dir.")
# Out:
# Patched train.py to respect overridden data_dir.

# %%
# === Cell 5 (fixed) ===
import os
from pathlib import Path

os.chdir(REPO_DIR)
# !python train.py
os.chdir("..")
# Out:
# [train.py] Loaded override from /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/out_onegroup/config_override.json
# tokens per iteration will be: 81,920
# /home/STUDENTS/mc1836/miniconda3/envs/torch/lib/python3.11/site-packages/torch/backends/__init__.py:46: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   self.setter(val)
# found vocab_size = 65 (inside /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/data/shakespeare_char/meta.pkl)
# Initializing a new model from scratch
# number of parameters: 18.91M
# num decayed parameter tensors: 26, with 19,038,720 parameters
# num non-decayed parameter tensors: 13, with 6,656 parameters
# using fused AdamW: True
# step 0: train loss 4.3528, val loss 4.3564
# iter 0: loss 4.3319, time 2064.83ms, mfu -100.00%
# iter 1: loss 4.1411, time 409.51ms, mfu -100.00%
# iter 2: loss 3.8304, time 431.16ms, mfu -100.00%
# iter 3: loss 3.6151, time 577.54ms, mfu -100.00%
# iter 4: loss 3.5258, time 474.22ms, mfu -100.00%
# iter 5: loss 3.3729, time 596.74ms, mfu 5.41%
# iter 6: loss 3.2985, time 530.27ms, mfu 5.48%
# iter 7: loss 3.2072, time 399.61ms, mfu 5.74%
# iter 8: loss 3.1330, time 519.18ms, mfu 5.78%
# iter 9: loss 3.1442, time 460.75ms, mfu 5.91%
# iter 10: loss 3.0170, time 467.83ms, mfu 6.01%
# iter 11: loss 3.0551, time 402.04ms, mfu 6.21%
# iter 12: loss 2.9719, time 402.77ms, mfu 6.39%
# iter 13: loss 2.9260, time 646.79ms, mfu 6.25%
# iter 14: loss 2.9265, time 397.99ms, mfu 6.43%
# iter 15: loss 2.8636, time 411.54ms, mfu 6.58%
# iter 16: loss 2.8577, time 400.86ms, mfu 6.72%
# iter 17: loss 2.8112, time 580.01ms, mfu 6.61%
# iter 18: loss 2.6827, time 649.89ms, mfu 6.44%
# iter 19: loss 2.6732, time 460.68ms, mfu 6.50%
# iter 20: loss 2.6865, time 564.30ms, mfu 6.42%
# iter 21: loss 2.6713, time 531.96ms, mfu 6.39%
# iter 22: loss 2.6591, time 408.35ms, mfu 6.54%
# iter 23: loss 2.6437, time 428.59ms, mfu 6.64%
# iter 24: loss 2.6333, time 557.48ms, mfu 6.55%
# iter 25: loss 2.5911, time 550.75ms, mfu 6.48%
# iter 26: loss 2.5890, time 415.31ms, mfu 6.61%
# iter 27: loss 2.5474, time 416.84ms, mfu 6.73%
# iter 28: loss 2.5980, time 460.23ms, mfu 6.75%
# iter 29: loss 2.5904, time 475.98ms, mfu 6.76%
# iter 30: loss 2.5918, time 590.80ms, mfu 6.63%
# iter 31: loss 2.5453, time 312.64ms, mfu 7.00%
# iter 32: loss 2.5067, time 333.51ms, mfu 7.26%
# iter 33: loss 2.5199, time 368.64ms, mfu 7.41%
# iter 34: loss 2.5393, time 520.90ms, mfu 7.29%
# iter 35: loss 2.5403, time 370.02ms, mfu 7.44%
# iter 36: loss 2.5475, time 347.07ms, mfu 7.62%
# iter 37: loss 2.4877, time 625.91ms, mfu 7.38%
# iter 38: loss 2.4798, time 686.61ms, mfu 7.11%
# iter 39: loss 2.5685, time 395.00ms, mfu 7.21%
# iter 40: loss 2.4858, time 465.08ms, mfu 7.19%
# iter 41: loss 2.5268, time 556.46ms, mfu 7.05%
# iter 42: loss 2.5420, time 459.45ms, mfu 7.05%
# iter 43: loss 2.4653, time 499.12ms, mfu 6.99%
# iter 44: loss 2.5050, time 411.45ms, mfu 7.07%
# iter 45: loss 2.5022, time 419.09ms, mfu 7.14%
# iter 46: loss 2.5410, time 487.04ms, mfu 7.09%
# iter 47: loss 2.5117, time 405.51ms, mfu 7.17%
# iter 48: loss 2.4948, time 430.05ms, mfu 7.21%
# iter 49: loss 2.4777, time 369.76ms, mfu 7.36%
# step 50: train loss 2.4558, val loss 2.4823
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/out_group4
# iter 50: loss 2.4694, time 1805.20ms, mfu 6.80%
# iter 51: loss 2.4829, time 461.16ms, mfu 6.82%
# iter 52: loss 2.4480, time 393.82ms, mfu 6.96%
# iter 53: loss 2.4408, time 536.53ms, mfu 6.86%
# iter 54: loss 2.4853, time 693.69ms, mfu 6.64%
# iter 55: loss 2.4135, time 687.87ms, mfu 6.45%
# iter 56: loss 2.4642, time 436.72ms, mfu 6.54%
# iter 57: loss 2.4413, time 419.91ms, mfu 6.66%
# iter 58: loss 2.4682, time 417.69ms, mfu 6.76%
# iter 59: loss 2.4753, time 408.84ms, mfu 6.88%
# iter 60: loss 2.4073, time 417.59ms, mfu 6.96%
# iter 61: loss 2.4280, time 410.05ms, mfu 7.05%
# iter 62: loss 2.4981, time 626.30ms, mfu 6.86%
# iter 63: loss 2.4771, time 368.84ms, mfu 7.05%
# iter 64: loss 2.4287, time 472.24ms, mfu 7.03%
# iter 65: loss 2.3976, time 570.95ms, mfu 6.89%
# iter 66: loss 2.4039, time 543.50ms, mfu 6.80%
# iter 67: loss 2.4136, time 471.94ms, mfu 6.80%
# iter 68: loss 2.4300, time 428.67ms, mfu 6.87%
# iter 69: loss 2.3810, time 466.86ms, mfu 6.88%
# iter 70: loss 2.4430, time 456.30ms, mfu 6.90%
# iter 71: loss 2.3841, time 572.05ms, mfu 6.77%
# iter 72: loss 2.4475, time 472.62ms, mfu 6.78%
# iter 73: loss 2.4521, time 412.28ms, mfu 6.88%
# iter 74: loss 2.4665, time 406.31ms, mfu 6.99%
# iter 75: loss 2.4058, time 432.17ms, mfu 7.04%
# iter 76: loss 2.4343, time 426.62ms, mfu 7.09%
# iter 77: loss 2.4550, time 544.35ms, mfu 6.97%
# iter 78: loss 2.4651, time 551.52ms, mfu 6.86%
# iter 79: loss 2.4451, time 484.55ms, mfu 6.84%
# iter 80: loss 2.4512, time 474.98ms, mfu 6.84%
# iter 81: loss 2.4609, time 393.35ms, mfu 6.97%
# iter 82: loss 2.4237, time 453.52ms, mfu 6.99%
# iter 83: loss 2.4611, time 468.22ms, mfu 6.98%
# iter 84: loss 2.4079, time 486.11ms, mfu 6.94%
# iter 85: loss 2.4433, time 417.59ms, mfu 7.02%
# iter 86: loss 2.4389, time 392.59ms, mfu 7.14%
# iter 87: loss 2.3802, time 538.32ms, mfu 7.03%
# iter 88: loss 2.3972, time 566.03ms, mfu 6.90%
# iter 89: loss 2.3792, time 411.90ms, mfu 6.99%
# iter 90: loss 2.3996, time 441.03ms, mfu 7.02%
# iter 91: loss 2.4371, time 482.88ms, mfu 6.99%
# iter 92: loss 2.4568, time 401.04ms, mfu 7.09%
# iter 93: loss 2.4012, time 579.30ms, mfu 6.94%
# iter 94: loss 2.4545, time 534.08ms, mfu 6.85%
# iter 95: loss 2.3635, time 417.90ms, mfu 6.94%
# iter 96: loss 2.4155, time 427.18ms, mfu 7.00%
# iter 97: loss 2.4160, time 457.18ms, mfu 7.01%
# iter 98: loss 2.3541, time 459.99ms, mfu 7.01%
# iter 99: loss 2.4068, time 434.47ms, mfu 7.05%
# step 100: train loss 2.3618, val loss 2.3826
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/out_group4
# iter 100: loss 2.3752, time 1792.96ms, mfu 6.52%
# iter 101: loss 2.3651, time 535.68ms, mfu 6.47%
# iter 102: loss 2.3903, time 458.26ms, mfu 6.53%
# iter 103: loss 2.3688, time 461.66ms, mfu 6.58%
# iter 104: loss 2.3821, time 670.39ms, mfu 6.40%
# iter 105: loss 2.4511, time 477.61ms, mfu 6.44%
# iter 106: loss 2.3656, time 426.03ms, mfu 6.55%
# iter 107: loss 2.3630, time 405.41ms, mfu 6.69%
# iter 108: loss 2.4220, time 404.88ms, mfu 6.82%
# iter 109: loss 2.3700, time 470.98ms, mfu 6.82%
# iter 110: loss 2.3417, time 403.58ms, mfu 6.94%
# iter 111: loss 2.3787, time 379.48ms, mfu 7.10%
# iter 112: loss 2.3388, time 410.19ms, mfu 7.17%
# iter 113: loss 2.3638, time 570.77ms, mfu 7.02%
# iter 114: loss 2.3511, time 675.33ms, mfu 6.80%
# iter 115: loss 2.2845, time 383.93ms, mfu 6.96%
# iter 116: loss 2.3921, time 413.55ms, mfu 7.04%
# iter 117: loss 2.2595, time 489.53ms, mfu 7.00%
# iter 118: loss 2.3534, time 626.65ms, mfu 6.81%
# iter 119: loss 2.3584, time 633.32ms, mfu 6.64%
# iter 120: loss 2.3695, time 412.15ms, mfu 6.76%
# iter 121: loss 2.3549, time 426.06ms, mfu 6.84%
# iter 122: loss 2.3668, time 391.97ms, mfu 6.98%
# iter 123: loss 2.2732, time 416.66ms, mfu 7.06%
# iter 124: loss 2.3185, time 434.94ms, mfu 7.09%
# iter 125: loss 2.3502, time 441.79ms, mfu 7.12%
# iter 126: loss 2.3069, time 466.50ms, mfu 7.10%
# iter 127: loss 2.3225, time 396.36ms, mfu 7.20%
# iter 128: loss 2.2681, time 560.11ms, mfu 7.06%
# iter 129: loss 2.3259, time 454.79ms, mfu 7.06%
# iter 130: loss 2.3200, time 469.01ms, mfu 7.04%
# iter 131: loss 2.2799, time 672.01ms, mfu 6.82%
# iter 132: loss 2.2785, time 421.58ms, mfu 6.90%
# iter 133: loss 2.2695, time 295.58ms, mfu 7.30%
# iter 134: loss 2.3247, time 305.40ms, mfu 7.63%
# iter 135: loss 2.2285, time 275.98ms, mfu 8.04%
# iter 136: loss 2.2898, time 314.73ms, mfu 8.26%
# iter 137: loss 2.2651, time 594.75ms, mfu 7.98%
# iter 138: loss 2.3101, time 421.87ms, mfu 7.94%
# iter 139: loss 2.2858, time 284.88ms, mfu 8.28%
# iter 140: loss 2.2172, time 287.98ms, mfu 8.57%
# iter 141: loss 2.1663, time 297.71ms, mfu 8.80%
# iter 142: loss 2.2538, time 330.86ms, mfu 8.90%
# iter 143: loss 2.2503, time 490.28ms, mfu 8.66%
# iter 144: loss 2.2811, time 468.37ms, mfu 8.49%
# iter 145: loss 2.2184, time 522.86ms, mfu 8.26%
# iter 146: loss 2.2309, time 438.73ms, mfu 8.17%
# iter 147: loss 2.2223, time 487.98ms, mfu 8.01%
# iter 148: loss 2.2644, time 348.90ms, mfu 8.13%
# iter 149: loss 2.2609, time 397.91ms, mfu 8.13%
# step 150: train loss 2.1899, val loss 2.2398
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/out_group4
# iter 150: loss 2.2646, time 1383.47ms, mfu 7.55%
# iter 151: loss 2.2340, time 337.82ms, mfu 7.75%
# iter 152: loss 2.1726, time 301.50ms, mfu 8.05%
# iter 153: loss 2.2315, time 307.58ms, mfu 8.29%
# iter 154: loss 2.2210, time 381.01ms, mfu 8.31%
# iter 155: loss 2.2680, time 592.55ms, mfu 8.02%
# iter 156: loss 2.2271, time 313.24ms, mfu 8.25%
# iter 157: loss 2.2070, time 578.06ms, mfu 7.99%
# iter 158: loss 2.2218, time 483.15ms, mfu 7.85%
# iter 159: loss 2.3059, time 537.25ms, mfu 7.67%
# iter 160: loss 2.2337, time 658.02ms, mfu 7.39%
# iter 161: loss 2.2397, time 249.27ms, mfu 7.95%
# iter 162: loss 2.1778, time 249.01ms, mfu 8.45%
# iter 163: loss 2.2238, time 262.84ms, mfu 8.83%
# iter 164: loss 2.2815, time 330.79ms, mfu 8.93%
# iter 165: loss 2.1819, time 539.52ms, mfu 8.63%
# iter 166: loss 2.1569, time 308.62ms, mfu 8.81%
# iter 167: loss 2.1662, time 336.52ms, mfu 8.89%
# iter 168: loss 2.1725, time 326.00ms, mfu 8.99%
# iter 169: loss 2.1356, time 338.97ms, mfu 9.05%
# iter 170: loss 2.1893, time 426.04ms, mfu 8.90%
# iter 171: loss 2.1966, time 264.50ms, mfu 9.23%
# iter 172: loss 2.1957, time 267.49ms, mfu 9.51%
# iter 173: loss 2.1769, time 288.93ms, mfu 9.68%
# iter 174: loss 2.2002, time 433.44ms, mfu 9.46%
# iter 175: loss 2.1339, time 445.32ms, mfu 9.23%
# iter 176: loss 2.1154, time 325.94ms, mfu 9.30%
# iter 177: loss 2.1784, time 661.59ms, mfu 8.86%
# iter 178: loss 2.1804, time 704.61ms, mfu 8.43%
# iter 179: loss 2.1484, time 470.36ms, mfu 8.27%
# iter 180: loss 2.0990, time 276.72ms, mfu 8.61%
# iter 181: loss 2.1463, time 266.40ms, mfu 8.96%
# iter 182: loss 2.1355, time 271.85ms, mfu 9.25%
# iter 183: loss 2.1146, time 241.38ms, mfu 9.67%
# iter 184: loss 2.1452, time 369.97ms, mfu 9.57%
# iter 185: loss 2.1506, time 702.33ms, mfu 9.07%
# iter 186: loss 2.1557, time 325.41ms, mfu 9.16%
# iter 187: loss 2.1463, time 279.20ms, mfu 9.40%
# iter 188: loss 2.1168, time 450.34ms, mfu 9.18%
# iter 189: loss 2.0776, time 285.80ms, mfu 9.39%
# iter 190: loss 2.0531, time 290.88ms, mfu 9.56%
# iter 191: loss 2.1222, time 317.00ms, mfu 9.62%
# iter 192: loss 2.0047, time 226.46ms, mfu 10.08%
# iter 193: loss 2.1258, time 246.92ms, mfu 10.38%
# iter 194: loss 2.1262, time 715.23ms, mfu 9.80%
# iter 195: loss 2.1151, time 633.19ms, mfu 9.33%
# iter 196: loss 1.9881, time 306.98ms, mfu 9.44%
# iter 197: loss 2.0529, time 422.29ms, mfu 9.26%
# iter 198: loss 2.1097, time 232.41ms, mfu 9.73%
# iter 199: loss 2.0984, time 239.50ms, mfu 10.10%
# step 200: train loss 2.0065, val loss 2.0941
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/out_group4
# iter 200: loss 2.0621, time 1161.59ms, mfu 9.37%
# iter 201: loss 2.0840, time 221.55ms, mfu 9.89%
# iter 202: loss 2.0547, time 234.82ms, mfu 10.27%
# iter 203: loss 2.0620, time 213.81ms, mfu 10.76%
# iter 204: loss 2.0043, time 445.62ms, mfu 10.41%
# iter 205: loss 2.0297, time 362.67ms, mfu 10.25%
# iter 206: loss 2.0755, time 237.97ms, mfu 10.59%
# iter 207: loss 2.0276, time 244.32ms, mfu 10.85%
# iter 208: loss 2.0935, time 240.72ms, mfu 11.10%
# iter 209: loss 2.0732, time 246.44ms, mfu 11.30%
# iter 210: loss 2.0208, time 270.69ms, mfu 11.37%
# iter 211: loss 2.0721, time 434.96ms, mfu 10.97%
# iter 212: loss 2.0944, time 224.54ms, mfu 11.31%
# iter 213: loss 2.0230, time 233.77ms, mfu 11.56%
# iter 214: loss 1.9670, time 421.48ms, mfu 11.17%
# iter 215: loss 1.9996, time 288.23ms, mfu 11.17%
# iter 216: loss 1.9957, time 263.99ms, mfu 11.28%
# iter 217: loss 1.9891, time 220.20ms, mfu 11.62%
# iter 218: loss 2.0554, time 226.99ms, mfu 11.88%
# iter 219: loss 1.9989, time 399.16ms, mfu 11.50%
# iter 220: loss 2.0153, time 406.62ms, mfu 11.14%
# iter 221: loss 2.0432, time 261.28ms, mfu 11.26%
# iter 222: loss 1.9752, time 249.91ms, mfu 11.43%
# iter 223: loss 1.9817, time 207.87ms, mfu 11.84%
# iter 224: loss 1.9856, time 286.24ms, mfu 11.78%
# iter 225: loss 2.0030, time 527.32ms, mfu 11.22%
# iter 226: loss 1.9603, time 231.17ms, mfu 11.49%
# iter 227: loss 1.9430, time 249.00ms, mfu 11.64%
# iter 228: loss 1.8737, time 215.61ms, mfu 11.97%
# iter 229: loss 1.8239, time 369.89ms, mfu 11.65%
# iter 230: loss 1.9105, time 324.05ms, mfu 11.48%
# iter 231: loss 1.9750, time 242.76ms, mfu 11.66%
# iter 232: loss 1.9574, time 350.20ms, mfu 11.41%
# iter 233: loss 1.9843, time 315.95ms, mfu 11.29%
# iter 234: loss 1.9188, time 220.35ms, mfu 11.63%
# iter 235: loss 1.9167, time 264.14ms, mfu 11.69%
# iter 236: loss 1.9592, time 261.42ms, mfu 11.75%
# iter 237: loss 1.9235, time 275.64ms, mfu 11.75%
# iter 238: loss 1.9206, time 196.60ms, mfu 12.22%
# iter 239: loss 1.9878, time 263.75ms, mfu 12.22%
# iter 240: loss 1.8999, time 496.91ms, mfu 11.65%
# iter 241: loss 2.0369, time 337.23ms, mfu 11.44%
# iter 242: loss 1.9688, time 276.83ms, mfu 11.46%
# iter 243: loss 1.9096, time 239.92ms, mfu 11.66%
# iter 244: loss 1.8966, time 225.65ms, mfu 11.92%
# iter 245: loss 1.8519, time 356.51ms, mfu 11.64%
# iter 246: loss 1.9149, time 429.61ms, mfu 11.22%
# iter 247: loss 1.8674, time 222.39ms, mfu 11.55%
# iter 248: loss 1.9044, time 313.02ms, mfu 11.43%
# iter 249: loss 1.9173, time 361.15ms, mfu 11.18%
# step 250: train loss 1.8355, val loss 1.9682
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/out_group4
# iter 250: loss 1.9401, time 1101.72ms, mfu 10.36%
# iter 251: loss 1.8977, time 228.60ms, mfu 10.73%
# iter 252: loss 1.9070, time 217.89ms, mfu 11.14%
# iter 253: loss 1.9414, time 275.42ms, mfu 11.20%
# iter 254: loss 1.8382, time 291.70ms, mfu 11.18%
# iter 255: loss 1.9582, time 248.05ms, mfu 11.37%
# iter 256: loss 1.8181, time 247.43ms, mfu 11.53%
# iter 257: loss 1.8013, time 248.11ms, mfu 11.68%
# iter 258: loss 1.8497, time 544.54ms, mfu 11.11%
# iter 259: loss 1.9147, time 275.59ms, mfu 11.17%
# iter 260: loss 1.9191, time 245.73ms, mfu 11.36%
# iter 261: loss 1.8824, time 197.90ms, mfu 11.86%
# iter 262: loss 1.8484, time 225.11ms, mfu 12.11%
# iter 263: loss 1.8891, time 520.57ms, mfu 11.52%
# iter 264: loss 1.9312, time 436.08ms, mfu 11.10%
# iter 265: loss 1.7695, time 228.38ms, mfu 11.41%
# iter 266: loss 1.8902, time 241.67ms, mfu 11.60%
# iter 267: loss 1.8488, time 197.58ms, mfu 12.08%
# iter 268: loss 1.9356, time 193.86ms, mfu 12.53%
# iter 269: loss 1.7109, time 173.94ms, mfu 13.13%
# iter 270: loss 1.8045, time 167.77ms, mfu 13.75%
# iter 271: loss 1.8745, time 171.34ms, mfu 14.25%
# iter 272: loss 1.9035, time 171.87ms, mfu 14.71%
# iter 273: loss 1.7862, time 173.44ms, mfu 15.10%
# iter 274: loss 1.8720, time 170.94ms, mfu 15.48%
# iter 275: loss 1.8761, time 169.78ms, mfu 15.83%
# iter 276: loss 1.8115, time 187.02ms, mfu 15.97%
# iter 277: loss 1.8474, time 188.88ms, mfu 16.08%
# iter 278: loss 1.7591, time 175.04ms, mfu 16.32%
# iter 279: loss 1.8463, time 177.69ms, mfu 16.50%
# iter 280: loss 1.8329, time 179.21ms, mfu 16.65%
# iter 281: loss 1.8352, time 175.03ms, mfu 16.83%
# iter 282: loss 1.7679, time 176.63ms, mfu 16.98%
# iter 283: loss 1.8408, time 176.92ms, mfu 17.10%
# iter 284: loss 1.8811, time 172.52ms, mfu 17.26%
# iter 285: loss 1.8709, time 178.56ms, mfu 17.34%
# iter 286: loss 1.8580, time 173.22ms, mfu 17.47%
# iter 287: loss 1.8928, time 187.65ms, mfu 17.45%
# iter 288: loss 1.7679, time 180.18ms, mfu 17.49%
# iter 289: loss 1.8350, time 174.07ms, mfu 17.60%
# iter 290: loss 1.7976, time 177.26ms, mfu 17.66%
# iter 291: loss 1.8303, time 196.26ms, mfu 17.54%
# iter 292: loss 1.7991, time 187.67ms, mfu 17.50%
# iter 293: loss 1.8371, time 173.84ms, mfu 17.61%
# iter 294: loss 1.7267, time 175.75ms, mfu 17.69%
# iter 295: loss 1.6120, time 187.47ms, mfu 17.64%
# iter 296: loss 1.7892, time 180.49ms, mfu 17.66%
# iter 297: loss 1.7390, time 183.68ms, mfu 17.65%
# iter 298: loss 1.7585, time 186.61ms, mfu 17.62%
# iter 299: loss 1.7878, time 175.23ms, mfu 17.70%
# step 300: train loss 1.6915, val loss 1.8552
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/out_group4
# iter 300: loss 1.6948, time 812.08ms, mfu 16.33%
# iter 301: loss 1.7817, time 173.03ms, mfu 16.56%
# iter 302: loss 1.8016, time 171.83ms, mfu 16.78%
# iter 303: loss 1.8739, time 175.57ms, mfu 16.94%
# iter 304: loss 1.8425, time 173.90ms, mfu 17.10%
# iter 305: loss 1.8145, time 173.72ms, mfu 17.25%
# iter 306: loss 1.7266, time 170.08ms, mfu 17.42%
# iter 307: loss 1.7516, time 173.46ms, mfu 17.54%
# iter 308: loss 1.8581, time 172.42ms, mfu 17.66%
# iter 309: loss 1.8287, time 168.37ms, mfu 17.81%
# iter 310: loss 1.7264, time 175.53ms, mfu 17.87%
# iter 311: loss 1.7638, time 174.65ms, mfu 17.93%
# iter 312: loss 1.6601, time 171.31ms, mfu 18.02%
# iter 313: loss 1.8434, time 178.59ms, mfu 18.03%
# iter 314: loss 1.7560, time 172.77ms, mfu 18.09%
# iter 315: loss 1.7582, time 175.92ms, mfu 18.12%
# iter 316: loss 1.7269, time 172.76ms, mfu 18.17%
# iter 317: loss 1.8172, time 168.35ms, mfu 18.27%
# iter 318: loss 1.6548, time 172.40ms, mfu 18.32%
# iter 319: loss 1.8085, time 185.24ms, mfu 18.23%
# iter 320: loss 1.7313, time 179.13ms, mfu 18.21%
# iter 321: loss 1.7008, time 179.92ms, mfu 18.18%
# iter 322: loss 1.7440, time 181.00ms, mfu 18.15%
# iter 323: loss 1.6673, time 179.47ms, mfu 18.13%
# iter 324: loss 1.7413, time 176.90ms, mfu 18.14%
# iter 325: loss 1.6868, time 179.14ms, mfu 18.13%
# iter 326: loss 1.6549, time 179.88ms, mfu 18.11%
# iter 327: loss 1.7362, time 172.48ms, mfu 18.17%
# iter 328: loss 1.7426, time 185.30ms, mfu 18.09%
# iter 329: loss 1.6781, time 178.36ms, mfu 18.09%
# iter 330: loss 1.6959, time 180.67ms, mfu 18.07%
# iter 331: loss 1.7517, time 179.50ms, mfu 18.06%
# iter 332: loss 1.7110, time 175.51ms, mfu 18.10%
# iter 333: loss 1.7602, time 171.56ms, mfu 18.17%
# iter 334: loss 1.7422, time 180.26ms, mfu 18.14%
# iter 335: loss 1.7543, time 195.07ms, mfu 17.98%
# iter 336: loss 1.7064, time 176.50ms, mfu 18.01%
# iter 337: loss 1.7417, time 173.28ms, mfu 18.07%
# iter 338: loss 1.7458, time 184.59ms, mfu 18.01%
# iter 339: loss 1.7592, time 182.72ms, mfu 17.98%
# iter 340: loss 1.7143, time 178.48ms, mfu 17.99%
# iter 341: loss 1.6209, time 189.92ms, mfu 17.89%
# iter 342: loss 1.7007, time 174.98ms, mfu 17.95%
# iter 343: loss 1.7323, time 177.27ms, mfu 17.97%
# iter 344: loss 1.7084, time 188.26ms, mfu 17.89%
# iter 345: loss 1.7317, time 175.83ms, mfu 17.94%
# iter 346: loss 1.7016, time 184.15ms, mfu 17.89%
# iter 347: loss 1.7091, time 165.94ms, mfu 18.05%
# iter 348: loss 1.7502, time 166.41ms, mfu 18.18%
# iter 349: loss 1.7364, time 170.23ms, mfu 18.26%
# step 350: train loss 1.6152, val loss 1.7928
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/out_group4
# iter 350: loss 1.7298, time 724.31ms, mfu 16.88%
# iter 351: loss 1.6705, time 167.49ms, mfu 17.12%
# iter 352: loss 1.6417, time 168.31ms, mfu 17.33%
# iter 353: loss 1.6880, time 180.39ms, mfu 17.38%
# iter 354: loss 1.6579, time 192.95ms, mfu 17.32%
# iter 355: loss 1.7715, time 174.56ms, mfu 17.43%
# iter 356: loss 1.6544, time 174.88ms, mfu 17.54%
# iter 357: loss 1.7004, time 177.48ms, mfu 17.60%
# iter 358: loss 1.6855, time 172.17ms, mfu 17.72%
# iter 359: loss 1.6961, time 179.69ms, mfu 17.74%
# iter 360: loss 1.7092, time 184.10ms, mfu 17.72%
# iter 361: loss 1.6112, time 180.02ms, mfu 17.74%
# iter 362: loss 1.6916, time 183.90ms, mfu 17.72%
# iter 363: loss 1.6420, time 172.55ms, mfu 17.82%
# iter 364: loss 1.6787, time 186.27ms, mfu 17.77%
# iter 365: loss 1.6615, time 180.53ms, mfu 17.78%
# iter 366: loss 1.7295, time 171.89ms, mfu 17.88%
# iter 367: loss 1.6790, time 175.17ms, mfu 17.94%
# iter 368: loss 1.7018, time 189.15ms, mfu 17.85%
# iter 369: loss 1.6466, time 178.49ms, mfu 17.87%
# iter 370: loss 1.7194, time 183.86ms, mfu 17.84%
# iter 371: loss 1.6825, time 188.15ms, mfu 17.77%
# iter 372: loss 1.6166, time 188.33ms, mfu 17.71%
# iter 373: loss 1.5565, time 193.43ms, mfu 17.61%
# iter 374: loss 1.6359, time 188.51ms, mfu 17.56%
# iter 375: loss 1.6936, time 180.54ms, mfu 17.59%
# iter 376: loss 1.6864, time 183.20ms, mfu 17.59%
# iter 377: loss 1.7267, time 177.82ms, mfu 17.65%
# iter 378: loss 1.6417, time 182.73ms, mfu 17.65%
# iter 379: loss 1.5944, time 176.53ms, mfu 17.71%
# iter 380: loss 1.6719, time 177.85ms, mfu 17.76%
# iter 381: loss 1.6041, time 169.44ms, mfu 17.89%
# iter 382: loss 1.6990, time 179.51ms, mfu 17.89%
# iter 383: loss 1.5959, time 201.03ms, mfu 17.71%
# iter 384: loss 1.6891, time 184.51ms, mfu 17.69%
# iter 385: loss 1.6841, time 179.75ms, mfu 17.72%
# iter 386: loss 1.6797, time 181.05ms, mfu 17.73%
# iter 387: loss 1.6402, time 186.82ms, mfu 17.68%
# iter 388: loss 1.6102, time 183.00ms, mfu 17.68%
# iter 389: loss 1.6524, time 180.66ms, mfu 17.70%
# iter 390: loss 1.5714, time 180.82ms, mfu 17.71%
# iter 391: loss 1.7164, time 173.70ms, mfu 17.80%
# iter 392: loss 1.7446, time 182.94ms, mfu 17.78%
# iter 393: loss 1.6364, time 185.20ms, mfu 17.75%
# iter 394: loss 1.7227, time 178.69ms, mfu 17.78%
# iter 395: loss 1.7037, time 174.15ms, mfu 17.85%
# iter 396: loss 1.7203, time 178.65ms, mfu 17.88%
# iter 397: loss 1.7238, time 176.07ms, mfu 17.92%
# iter 398: loss 1.6952, time 173.18ms, mfu 17.99%
# iter 399: loss 1.6078, time 168.62ms, mfu 18.11%
# step 400: train loss 1.5620, val loss 1.7344
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/out_group4
# iter 400: loss 1.6887, time 778.02ms, mfu 16.71%
# iter 401: loss 1.5562, time 180.37ms, mfu 16.83%
# iter 402: loss 1.6089, time 176.04ms, mfu 16.98%
# iter 403: loss 1.7442, time 181.06ms, mfu 17.06%
# iter 404: loss 1.7231, time 171.80ms, mfu 17.24%
# iter 405: loss 1.6312, time 182.71ms, mfu 17.28%
# iter 406: loss 1.5966, time 170.21ms, mfu 17.45%
# iter 407: loss 1.5833, time 179.24ms, mfu 17.50%
# iter 408: loss 1.7013, time 198.05ms, mfu 17.38%
# iter 409: loss 1.5688, time 204.08ms, mfu 17.23%
# iter 410: loss 1.6690, time 195.89ms, mfu 17.15%
# iter 411: loss 1.5617, time 189.53ms, mfu 17.14%
# iter 412: loss 1.5912, time 205.83ms, mfu 16.99%
# iter 413: loss 1.6900, time 204.21ms, mfu 16.87%
# iter 414: loss 1.6112, time 168.43ms, mfu 17.10%
# iter 415: loss 1.5700, time 177.13ms, mfu 17.22%
# iter 416: loss 1.5792, time 376.06ms, mfu 16.35%
# iter 417: loss 1.6001, time 181.83ms, mfu 16.49%
# iter 418: loss 1.6109, time 199.65ms, mfu 16.46%
# iter 419: loss 1.5686, time 177.58ms, mfu 16.63%
# iter 420: loss 1.6860, time 201.98ms, mfu 16.57%
# iter 421: loss 1.6309, time 188.10ms, mfu 16.62%
# iter 422: loss 1.5754, time 182.29ms, mfu 16.73%
# iter 423: loss 1.5914, time 194.78ms, mfu 16.72%
# iter 424: loss 1.6237, time 186.95ms, mfu 16.77%
# iter 425: loss 1.5501, time 197.86ms, mfu 16.73%
# iter 426: loss 1.7015, time 203.71ms, mfu 16.64%
# iter 427: loss 1.6863, time 204.05ms, mfu 16.56%
# iter 428: loss 1.6438, time 227.01ms, mfu 16.32%
# iter 429: loss 1.5784, time 535.60ms, mfu 15.29%
# iter 430: loss 1.6723, time 192.84ms, mfu 15.44%
# iter 431: loss 1.6438, time 200.84ms, mfu 15.50%
# iter 432: loss 1.6886, time 200.51ms, mfu 15.56%
# iter 433: loss 1.6349, time 197.11ms, mfu 15.64%
# iter 434: loss 1.5631, time 202.11ms, mfu 15.67%
# iter 435: loss 1.6607, time 199.18ms, mfu 15.73%
# iter 436: loss 1.5558, time 201.19ms, mfu 15.76%
# iter 437: loss 1.5408, time 197.40ms, mfu 15.82%
# iter 438: loss 1.6994, time 197.14ms, mfu 15.87%
# iter 439: loss 1.5886, time 200.66ms, mfu 15.89%
# iter 440: loss 1.6478, time 198.54ms, mfu 15.93%
# iter 441: loss 1.5694, time 207.15ms, mfu 15.90%
# iter 442: loss 1.5732, time 199.27ms, mfu 15.93%
# iter 443: loss 1.6015, time 219.97ms, mfu 15.80%
# iter 444: loss 1.5824, time 227.78ms, mfu 15.64%
# iter 445: loss 1.7053, time 219.94ms, mfu 15.54%
# iter 446: loss 1.5518, time 186.32ms, mfu 15.72%
# iter 447: loss 1.5975, time 202.23ms, mfu 15.74%
# iter 448: loss 1.6705, time 205.66ms, mfu 15.74%
# iter 449: loss 1.6915, time 250.09ms, mfu 15.45%
# step 450: train loss 1.5342, val loss 1.7171
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/out_group4
# iter 450: loss 1.5666, time 1205.26ms, mfu 14.18%
# iter 451: loss 1.5479, time 245.59ms, mfu 14.07%
# iter 452: loss 1.6177, time 227.32ms, mfu 14.09%
# iter 453: loss 1.5969, time 217.66ms, mfu 14.16%
# iter 454: loss 1.5445, time 297.23ms, mfu 13.83%
# iter 455: loss 1.5565, time 332.87ms, mfu 13.42%
# iter 456: loss 1.6319, time 209.77ms, mfu 13.61%
# iter 457: loss 1.6900, time 386.30ms, mfu 13.09%
# iter 458: loss 1.6316, time 480.36ms, mfu 12.45%
# iter 459: loss 1.5566, time 563.97ms, mfu 11.78%
# iter 460: loss 1.5434, time 235.82ms, mfu 11.97%
# iter 461: loss 1.6371, time 229.76ms, mfu 12.18%
# iter 462: loss 1.6793, time 233.03ms, mfu 12.34%
# iter 463: loss 1.6709, time 237.55ms, mfu 12.47%
# iter 464: loss 1.5140, time 204.49ms, mfu 12.80%
# iter 465: loss 1.6489, time 250.52ms, mfu 12.81%
# iter 466: loss 1.6649, time 250.84ms, mfu 12.81%
# iter 467: loss 1.5449, time 271.75ms, mfu 12.72%
# iter 468: loss 1.7022, time 338.66ms, mfu 12.40%
# iter 469: loss 1.5670, time 423.95ms, mfu 11.92%
# iter 470: loss 1.6076, time 262.37ms, mfu 11.96%
# iter 471: loss 1.6403, time 225.35ms, mfu 12.20%
# iter 472: loss 1.5429, time 412.22ms, mfu 11.76%
# iter 473: loss 1.5197, time 249.78ms, mfu 11.88%
# iter 474: loss 1.5897, time 208.79ms, mfu 12.23%
# iter 475: loss 1.6373, time 199.55ms, mfu 12.63%
# iter 476: loss 1.6351, time 212.97ms, mfu 12.88%
# iter 477: loss 1.6276, time 485.54ms, mfu 12.26%
# iter 478: loss 1.5847, time 606.19ms, mfu 11.56%
# iter 479: loss 1.5837, time 229.55ms, mfu 11.81%
# iter 480: loss 1.5774, time 258.18ms, mfu 11.88%
# iter 481: loss 1.5995, time 239.78ms, mfu 12.04%
# iter 482: loss 1.5906, time 216.23ms, mfu 12.33%
# iter 483: loss 1.6305, time 399.93ms, mfu 11.90%
# iter 484: loss 1.6411, time 232.69ms, mfu 12.10%
# iter 485: loss 1.6389, time 245.16ms, mfu 12.21%
# iter 486: loss 1.5823, time 420.89ms, mfu 11.75%
# iter 487: loss 1.5337, time 296.58ms, mfu 11.67%
# iter 488: loss 1.6202, time 264.95ms, mfu 11.72%
# iter 489: loss 1.5313, time 242.60ms, mfu 11.88%
# iter 490: loss 1.5436, time 227.36ms, mfu 12.11%
# iter 491: loss 1.6391, time 361.95ms, mfu 11.79%
# iter 492: loss 1.5597, time 394.02ms, mfu 11.43%
# iter 493: loss 1.5969, time 334.73ms, mfu 11.25%
# iter 494: loss 1.5508, time 474.72ms, mfu 10.81%
# iter 495: loss 1.5843, time 334.27ms, mfu 10.69%
# iter 496: loss 1.5902, time 235.12ms, mfu 10.99%
# iter 497: loss 1.6119, time 403.66ms, mfu 10.69%
# iter 498: loss 1.6578, time 220.61ms, mfu 11.09%
# iter 499: loss 1.6055, time 252.70ms, mfu 11.26%
# step 500: train loss 1.5131, val loss 1.7087
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/out_group4
# iter 500: loss 1.5855, time 1278.21ms, mfu 10.38%

# %%
# === Cell 6: plot curves (train, val, gap) ===
import os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

log_csv = str(Path(OUT_DIR) / "loss_log.csv")
if not os.path.exists(log_csv):
    raise SystemExit("No loss_log.csv yet. Let training run (eval_interval small helps).")

df = pd.read_csv(log_csv)
if df.empty:
    raise SystemExit("loss_log.csv is empty.")

# --- Training curve ---
dft = df[df["split"] == "train"].sort_values("iter")
if not dft.empty:
    plt.figure()
    plt.plot(dft["iter"], dft["loss"])
    plt.title("Training Loss Curve")
    plt.xlabel("Iteration")
    plt.ylabel("Loss")
    plt.show()
else:
    print("No 'train' rows in loss_log.csv")

# --- Validation curve ---
dfv = df[df["split"] == "val"].sort_values("iter")
if not dfv.empty:
    plt.figure()
    plt.plot(dfv["iter"], dfv["loss"])
    plt.title("Validation Loss Curve")
    plt.xlabel("Iteration")
    plt.ylabel("Loss")
    plt.show()
else:
    print("No 'val' rows yet (run longer or lower eval_interval).")

# --- Train–Val Gap (nearest-neighbor align val to the latest <= train iter) ---
if not dft.empty and not dfv.empty:
    t_iters = dft["iter"].to_numpy()
    t_loss  = dft["loss"].to_numpy()

    aligned = []
    for _, r in dfv.iterrows():
        v_it, v_loss = int(r["iter"]), float(r["loss"])
        # index of latest train iter <= v_it; fallback to first train iter
        idx = np.searchsorted(t_iters, v_it, side="right") - 1
        if idx < 0:
            idx = 0
        aligned.append((v_it, v_loss - t_loss[idx]))

    adf = pd.DataFrame(aligned, columns=["iter", "gap"])
    plt.figure()
    plt.plot(adf["iter"], adf["gap"])
    plt.title("Train–Val Loss Gap (Overfitting Indicator)")
    plt.xlabel("Iteration (val)")
    plt.ylabel("Val - Train")
    plt.show()
else:
    print("Not enough data for gap curve yet (need both train and val).")

# %%
# === Cell 7: params & memory from last checkpoint ===
import os, importlib.util, torch
from pathlib import Path

CKPT = str(Path(OUT_DIR) / "ckpt.pt")
if not os.path.exists(CKPT):
    raise SystemExit("No checkpoint found. Let training run past the first eval (Cell 3 sets always_save_checkpoint=True).")

# import model module
spec = importlib.util.spec_from_file_location("nanogpt_model", MODEL_PY)
mod  = importlib.util.module_from_spec(spec)
spec.loader.exec_module(mod)

ckpt = torch.load(CKPT, map_location="cpu")
model_args = ckpt.get("model_args") or ckpt.get("config") or {}
gcfg = mod.GPTConfig(**model_args)
model = mod.GPT(gcfg)
model.load_state_dict(ckpt["model"], strict=False)

# counts & memory
n_params = sum(p.numel() for p in model.parameters())
def human(b): 
    return f"{b/1024/1024:.2f} MB" if b < 1024**3 else f"{b/1024/1024/1024:.2f} GB"
model_mem = n_params * 2           # bf16/fp16 weights ~2 bytes each
opt_states_same = n_params * 2 * 2 # two moments at same dtype
opt_states_fp32 = n_params * 2 * 4 # conservative fp32 optimizer states

print("Model args:", model_args)
print(f"Total parameters: {n_params:,}")
print("Model weights (fp16/bf16):", human(model_mem))
print("Optimizer states (same):  ", human(opt_states_same))
print("Optimizer states (fp32):  ", human(opt_states_fp32))
print("Total optimistic:", human(model_mem + opt_states_same))
print("Total conservative:", human(model_mem + opt_states_fp32))
# Out:
# number of parameters: 18.91M
# Model args: {'n_layer': 6, 'n_head': 8, 'n_embd': 512, 'block_size': 256, 'bias': False, 'vocab_size': 65, 'dropout': 0.1}
# Total parameters: 19,045,376
# Model weights (fp16/bf16): 36.33 MB
# Optimizer states (same):   72.65 MB
# Optimizer states (fp32):   145.30 MB
# Total optimistic: 108.98 MB
# Total conservative: 181.63 MB

# %%
# === Cell 8a: ensure checkpoint exists (create one quickly if missing) ===
import os, json, time, shlex
from pathlib import Path

repo = Path(REPO_DIR)
out_dir = Path(OUT_DIR)
ckpt = out_dir / "ckpt.pt"

if ckpt.exists():
    print("✅ Found checkpoint:", ckpt)
else:
    print("ℹ️ No checkpoint found at", ckpt)
    # Temporarily write a minimal override that forces an immediate eval+save and exits.
    temp_cfg = {
        "out_dir": str(out_dir),
        "data_dir": str(Path(DATA_DIR)),
        "eval_only": True,
        "always_save_checkpoint": True,
        # keep a tiny model so it's quick if the repo insists on building the net
        "block_size": 128, "n_layer": 2, "n_head": 2, "n_embd": 128,
        "batch_size": 8, "eval_iters": 10, "compile": False
    }
    tmp_override = out_dir / "config_override.json"
    tmp_override.write_text(json.dumps(temp_cfg, indent=2))
    print("Wrote temporary override →", tmp_override)

    # Run a one-off eval to save ckpt.pt
    cwd = os.getcwd()
    os.chdir(str(repo))
    ret = os.system("python train.py")
    os.chdir(cwd)

    if ckpt.exists():
        print("✅ Created checkpoint:", ckpt)
    else:
        raise SystemExit("❌ Could not create a checkpoint. Run training a bit (lower eval_interval) and retry.")
# Out:
# ✅ Found checkpoint: /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/out_onegroup/ckpt.pt

# %%
# === Cell 8b (safe): direct sampler with clamped top-k ===
import os, pickle, torch, time, importlib.util
from pathlib import Path

repo = Path(REPO_DIR)
out_dir = Path(OUT_DIR)
data_dir = Path(DATA_DIR)
ckpt_path = out_dir / "ckpt.pt"
meta_path = data_dir / "meta.pkl"
assert ckpt_path.exists(), f"Checkpoint not found: {ckpt_path}"
assert meta_path.exists(), f"meta.pkl not found: {meta_path}"

with open(meta_path, "rb") as f:
    meta = pickle.load(f)
stoi, itos = meta["stoi"], meta["itos"]

def encode(s): return [stoi[c] for c in s if c in stoi]
def decode(ids): return "".join(itos[i] for i in ids)

spec = importlib.util.spec_from_file_location("nanogpt_model", str(repo / "model.py"))
mod  = importlib.util.module_from_spec(spec); spec.loader.exec_module(mod)

ckpt = torch.load(str(ckpt_path), map_location="cpu")
model_args = ckpt.get("model_args") or ckpt.get("config") or {}
model = mod.GPT(mod.GPTConfig(**model_args))
model.load_state_dict(ckpt["model"], strict=False)
model.eval()

PROMPT = "In a quiet lab, the scientists examined the EEG signals and"
TEMPERATURE = 0.9
TOP_K = 80                 # will be clamped safely
MAX_NEW_TOKENS = 220

def top_k_logits(logits, k):
    if not k or k <= 0:
        return logits
    k = min(k, logits.size(-1))         # clamp to vocab size
    v, ix = torch.topk(logits, k, dim=-1)
    out = torch.full_like(logits, float("-inf"))
    out.scatter_(dim=-1, index=ix, src=v)
    return out

block_size = model.config.block_size
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)

ctx = torch.tensor([encode(PROMPT)], dtype=torch.long, device=device)
if ctx.size(1) == 0:
    ctx = torch.tensor([[stoi.get("\n", 0)]], dtype=torch.long, device=device)

generated = ctx.clone()
with torch.no_grad():
    for _ in range(MAX_NEW_TOKENS):
        idx_cond = generated[:, -block_size:]
        logits, _ = model(idx_cond)
        logits = logits[:, -1, :] / max(TEMPERATURE, 1e-6)
        logits = top_k_logits(logits, TOP_K)
        probs = torch.softmax(logits, dim=-1)
        next_id = torch.multinomial(probs, num_samples=1)
        generated = torch.cat([generated, next_id], dim=1)

text = decode(generated[0].tolist())
stamp = time.strftime("%Y%m%d-%H%M%S")
out_file = out_dir / f"sample_direct_T{TEMPERATURE}_K{TOP_K}_{stamp}.txt"
out_file.write_text(text, encoding="utf-8")
print("✅ Wrote sample →", out_file)
print("\n--- Preview ---\n")
print(text[:1000], "...\n")
# Out:
# number of parameters: 18.91M
# ✅ Wrote sample → /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/out_onegroup/sample_direct_T0.9_K80_20251028-183100.txt
#
# --- Preview ---
#
# In a quiet lab, the scientists examined the EEG signals and
# To unwhich maling treators your timence, and their
# This not state and and to me, this day:
# Then less what do store oadies disge.
#
# BANALO:
# Nothing thee, Hash my grounds flow you haffer
# My with the eart to my ment the liv ...

# %%
# === Cell 9: qualitative rubric & quick checklist ===
from pathlib import Path

rubric_text = """Qualitative Evaluation (score 1–5; add short notes)

1) Generated text quality & coherence: _____
   Note:
2) Long-range dependencies (≈100+ token consistency): _____
   Note:
3) Grammatical correctness: _____
   Note:
4) Style consistency with training data: _____
   Note:

Additional observations:
- Repetitions / loops:
- Contradictions:
- Topic drift:
- Strengths:
- Failure cases:
"""

rubric_path = Path(OUT_DIR) / "QUAL_RUBRIC.txt"
rubric_path.write_text(rubric_text, encoding="utf-8")
print("Rubric written →", rubric_path)

# Optional: preview the most recent generated sample
candidates = sorted(Path(OUT_DIR).glob("sample_direct_*.txt")) or sorted(Path(OUT_DIR).glob("sample_*.txt"))
if candidates:
    latest = candidates[-1]
    print("\n--- Latest sample preview:", latest.name, "---\n")
    print(latest.read_text(encoding="utf-8")[:1200], "...\n")
else:
    print("No sample file found yet. Run your sampling cell first (Cell 8).")
# Out:
# Rubric written → /home/STUDENTS/mc1836/projects/torch/Group 4/nanoGPT/out_onegroup/QUAL_RUBRIC.txt
#
# --- Latest sample preview: sample_direct_T0.9_K80_20251028-183100.txt ---
#
# In a quiet lab, the scientists examined the EEG signals and
# To unwhich maling treators your timence, and their
# This not state and and to me, this day:
# Then less what do store oadies disge.
#
# BANALO:
# Nothing thee, Hash my grounds flow you haffer
# My with the eart to my ment the liv ...
