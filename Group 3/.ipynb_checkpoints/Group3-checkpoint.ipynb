# %%
# === Cell 1: clone NanoGPT & set paths ===
import os, json, sys
from pathlib import Path

# clone (skip if already cloned)
if not Path("nanoGPT").exists():
    # !git clone https://github.com/karpathy/nanoGPT.git

REPO_DIR = str(Path("nanoGPT").resolve())
OUT_DIR  = str(Path(REPO_DIR) / "out_onegroup")   # keep our runs separate
DATA_DIR = str(Path(REPO_DIR) / "data" / "shakespeare_char")  # we'll use Tiny Shakespeare

TRAIN_PY  = str(Path(REPO_DIR) / "train.py")
MODEL_PY  = str(Path(REPO_DIR) / "model.py")
SAMPLE_PY = str(Path(REPO_DIR) / "sample.py")

os.makedirs(OUT_DIR, exist_ok=True)

print("REPO_DIR:", REPO_DIR)
print("OUT_DIR :", OUT_DIR)
print("Files exist:", {
    "train.py": os.path.exists(TRAIN_PY),
    "model.py": os.path.exists(MODEL_PY),
    "sample.py": os.path.exists(SAMPLE_PY),
})
# Out:
# Cloning into 'nanoGPT'...
# remote: Enumerating objects: 686, done.
# remote: Total 686 (delta 0), reused 0 (delta 0), pack-reused 686 (from 1)
# Receiving objects: 100% (686/686), 974.06 KiB | 6.63 MiB/s, done.
# Resolving deltas: 100% (380/380), done.
# REPO_DIR: /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT
# OUT_DIR : /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/out_onegroup
# Files exist: {'train.py': True, 'model.py': True, 'sample.py': True}

# %%
# !python nanoGPT/data/shakespeare_char/prepare.py
# Out:
# length of dataset in characters: 1,115,394
# all the unique characters:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# vocab size: 65
# train has 1,003,854 tokens
# val has 111,540 tokens

# %%
# === Cell 2: prepare Tiny Shakespeare data ===
import os
from pathlib import Path

# run the repo's prepare script
# %cd "$REPO_DIR"
# !python data/shakespeare_char/prepare.py
# %cd - > /dev/null

# confirm files
data_files = list(Path(DATA_DIR).glob("*"))
print("DATA_DIR:", DATA_DIR)
for p in data_files:
    print(" -", p.name)
# Out:
# /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT
# length of dataset in characters: 1,115,394
# all the unique characters:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# vocab size: 65
# train has 1,003,854 tokens
# val has 111,540 tokens
# [Errno 2] No such file or directory: '- > /dev/null'
# /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT
# DATA_DIR: /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/data/shakespeare_char
#  - input.txt
#  - val.bin
#  - meta.pkl
#  - readme.md
#  - train.bin
#  - prepare.py

# %%
# === Cell 3: write single-group config_override.json ===
import json, os
from pathlib import Path

# A reasonable "one group" student config (small & quick)
cfg = {
    # architecture
    "block_size": 128,
    "n_layer": 4,
    "n_head": 8,
    "n_embd": 512,
    "dropout": 0.1,
    # training
    "batch_size": 12,
    "max_iters": 500,
    "learning_rate": 3e-4,
    "weight_decay": 1e-1,
    "beta1": 0.9,
    "beta2": 0.95,
    "grad_clip": 1.0,
    "decay_lr": True,
    "warmup_iters": 50,
    "lr_decay_iters": 500,
    "min_lr": 1e-5,
    # eval/checkpoint cadence
    "eval_interval": 50,
    "eval_iters": 100,
    "always_save_checkpoint": True,
    "eval_only": False,
    # I/O
    "out_dir": str(Path(REPO_DIR) / "out_group3"),
    "data_dir": DATA_DIR,
    # speed / debug
    "compile": False
}

ovr_path = str(Path(OUT_DIR) / "config_override.json")
with open(ovr_path, "w") as f:
    json.dump(cfg, f, indent=2)

print("Wrote override ->", ovr_path)
print(json.dumps(cfg, indent=2))
# Out:
# Wrote override -> /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/out_onegroup/config_override.json
# {
#   "block_size": 128,
#   "n_layer": 4,
#   "n_head": 8,
#   "n_embd": 512,
#   "dropout": 0.1,
#   "batch_size": 12,
#   "max_iters": 500,
#   "learning_rate": 0.0003,
#   "weight_decay": 0.1,
#   "beta1": 0.9,
#   "beta2": 0.95,
#   "grad_clip": 1.0,
#   "decay_lr": true,
#   "warmup_iters": 50,
#   "lr_decay_iters": 500,
#   "min_lr": 1e-05,
#   "eval_interval": 50,
#   "eval_iters": 100,
#   "always_save_checkpoint": true,
#   "eval_only": false,
#   "out_dir": "/home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/out_group3",
#   "data_dir": "/home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/data/shakespeare_char",
#   "compile": false
# }

# %%
# === Cell 4: patch train.py (idempotent) ===
from pathlib import Path
import re

tp = Path(TRAIN_PY).read_text()

# 1) Ensure it loads our override JSON early (affects out_dir, data_dir, etc.)
if "BEGIN: config override loader (onegroup)" not in tp:
    insert_after = tp.find("# -----------------------------------------------------------------------------\nconfig_keys")
    if insert_after == -1:
        insert_after = 0
    loader = f"""
# ==== BEGIN: config override loader (onegroup) ====
import json as _json
try:
    _OVR = r"{ovr_path}"
    if os.path.exists(_OVR):
        with open(_OVR, "r") as _f:
            _ovr = _json.load(_f)
        def _set(name, default=None):
            globals()[name] = _ovr.get(name, globals().get(name, default))
        # core
        _set("block_size")
        _set("n_layer"); _set("n_head"); _set("n_embd")
        _set("dropout")
        _set("batch_size"); _set("max_iters")
        # opt
        _set("learning_rate"); _set("weight_decay")
        _set("beta1"); _set("beta2")
        _set("grad_clip")
        _set("decay_lr"); _set("warmup_iters"); _set("lr_decay_iters"); _set("min_lr")
        # io
        _set("out_dir"); _set("eval_interval"); _set("eval_iters")
        _set("always_save_checkpoint"); _set("eval_only")
        _set("compile")
        # dataset resolution
        globals()["data_dir"] = _ovr.get("data_dir", os.path.join('data', globals().get("dataset","openwebtext")))
        print(f"[train.py] Loaded override from {{_OVR}}")
except Exception as _e:
    print("[train.py] Override load failed:", _e)
# ==== END: config override loader (onegroup) ====
"""
    tp = tp.replace("config = {k: globals()[k] for k in config_keys} # will be useful for logging",
                    "config = {k: globals()[k] for k in config_keys} # will be useful for logging\n" + loader)

# 2) Loss logger defined BEFORE training loop
if "BEGIN: loss logger (onegroup)" not in tp:
    loss_logger = """
# ==== BEGIN: loss logger (onegroup) ====
import csv as _csv
try:
    os.makedirs(out_dir, exist_ok=True)
except Exception:
    out_dir = "out"
    os.makedirs(out_dir, exist_ok=True)
_loss_csv = os.path.join(out_dir, "loss_log.csv")
if not os.path.exists(_loss_csv):
    with open(_loss_csv, "w", newline="") as _f:
        _w = _csv.writer(_f); _w.writerow(["iter","split","loss"])
def _append_loss_row(it, split, loss):
    try:
        with open(_loss_csv, "a", newline="") as _f:
            _w = _csv.writer(_f); _w.writerow([int(it), str(split), float(loss)])
    except Exception as _e:
        print("[warn] could not write loss log:", _e)
# ==== END: loss logger (onegroup) ====
"""
    # put it after the get_lr function (safe place)
    anchor = "def get_lr(it):"
    idx = tp.find(anchor)
    if idx != -1:
        end = tp.find("\n", idx)
        tp = tp[:end] + "\n" + loss_logger + tp[end:]
    else:
        tp = tp + "\n" + loss_logger

# 3) Log eval losses inside estimate_loss() before return
if "eval loss log (onegroup)" not in tp:
    tp = re.sub(
        r"(def\s+estimate_loss\s*\(\)\s*:\s*\n(?:.|\n)*?return\s+out)",
        r"""def estimate_loss():
    out = {}
    model.eval()
    for split in ['train','val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            with ctx:
                logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    # === eval loss log (onegroup) ===
    try:
        for _s, _v in out.items():
            _append_loss_row(iter_num, _s, float(_v))
    except Exception as _e:
        print("[warn] eval loss log failed:", _e)
    return out""",
        tp, count=1, flags=re.DOTALL
    )

# 4) Log train loss once per iteration where it prints the iter line
if "train loss log (onegroup)" not in tp:
    tp = tp.replace(
        "print(f\"iter {iter_num}: loss {lossf:.4f}, time {dt*1000:.2f}ms, mfu {running_mfu*100:.2f}%\")",
        "print(f\"iter {iter_num}: loss {lossf:.4f}, time {dt*1000:.2f}ms, mfu {running_mfu*100:.2f}%\")\n"
        "        try:\n"
        "            _append_loss_row(iter_num, 'train', float(lossf))\n"
        "        except Exception as _e:\n"
        "            print('[warn] train loss log failed:', _e)"
    )

# 5) Switch to new GradScaler API (silence deprecation)
tp = tp.replace("torch.cuda.amp.GradScaler(", "torch.amp.GradScaler('cuda', ")

Path(TRAIN_PY).write_text(tp)
print("train.py patched ✅")
# Out:
# train.py patched ✅

# %%
# === FIX train.py indentation + logger placement ===
from pathlib import Path
import re, textwrap

tp_path = Path(REPO_DIR) / "train.py"
txt = tp_path.read_text()

# 1. remove any previously inserted logger blocks that caused the indent error
txt = re.sub(r"# ==== BEGIN: loss logger.*?# ==== END: loss logger.*?====", "", txt, flags=re.S)

# 2. inject clean logger block near top (right after imports)
logger_block = textwrap.dedent("""
# ==== BEGIN: loss logger (onegroup fixed) ====
import csv as _csv, os
_loss_csv = os.path.join(out_dir, "loss_log.csv")
os.makedirs(out_dir, exist_ok=True)
if not os.path.exists(_loss_csv):
    with open(_loss_csv, "w", newline="") as _f:
        _csv.writer(_f).writerow(["iter","split","loss"])

def _append_loss_row(it, split, loss):
    try:
        with open(_loss_csv, "a", newline="") as _f:
            _csv.writer(_f).writerow([int(it), str(split), float(loss)])
    except Exception as _e:
        print("[warn] could not write loss log:", _e)
# ==== END: loss logger (onegroup fixed) ====
""")

# place it right after first import block
insert_at = txt.find("from model import GPTConfig, GPT")
if insert_at != -1:
    end = txt.find("\n", insert_at) + 1
    txt = txt[:end] + logger_block + txt[end:]
else:
    txt = logger_block + "\n" + txt

tp_path.write_text(txt)
print("✅ train.py fixed: logger inserted at top-level (no indentation error).")
# Out:
# ✅ train.py fixed: logger inserted at top-level (no indentation error).

# %%
# !head -n 300 "$REPO_DIR/train.py" | grep "loss logger"
# Out:
# # ==== BEGIN: loss logger (onegroup fixed) ====
# # ==== END: loss logger (onegroup fixed) ====

# %%
# === FIX: move logger below out_dir definition ===
from pathlib import Path
import re, textwrap

tp_path = Path(REPO_DIR) / "train.py"
txt = tp_path.read_text()

# Remove any prior inserted logger blocks
txt = re.sub(r"# ==== BEGIN: loss logger.*?# ==== END: loss logger.*?====", "", txt, flags=re.S)

# Build clean logger block (depends on out_dir)
logger_block = textwrap.dedent("""
# ==== BEGIN: loss logger (onegroup fixed, after out_dir) ====
import csv as _csv, os
_loss_csv = os.path.join(out_dir, "loss_log.csv")
os.makedirs(out_dir, exist_ok=True)
if not os.path.exists(_loss_csv):
    with open(_loss_csv, "w", newline="") as _f:
        _csv.writer(_f).writerow(["iter","split","loss"])

def _append_loss_row(it, split, loss):
    try:
        with open(_loss_csv, "a", newline="") as _f:
            _csv.writer(_f).writerow([int(it), str(split), float(loss)])
    except Exception as _e:
        print("[warn] could not write loss log:", _e)
# ==== END: loss logger (onegroup fixed, after out_dir) ====
""")

# Find insertion point: right after the first occurrence of "out_dir ="
idx = txt.find("out_dir =")
if idx == -1:
    raise RuntimeError("Could not find 'out_dir =' in train.py; please verify file.")
line_end = txt.find("\n", idx)
patched = txt[:line_end+1] + logger_block + txt[line_end+1:]

tp_path.write_text(patched)
print("✅ Logger moved below out_dir definition. Ready to train again.")
# Out:
# ✅ Logger moved below out_dir definition. Ready to train again.

# %%
# --- Patch train.py: stop overwriting data_dir to 'data/openwebtext' ---
from pathlib import Path
import re

tp_path = Path(REPO_DIR) / "train.py"
txt = tp_path.read_text()

# Replace the hard assignment:
#   data_dir = os.path.join('data', dataset)
# with a guarded version that respects an override:
patched = re.sub(
    r"\bdata_dir\s*=\s*os\.path\.join\('data',\s*dataset\)",
    "data_dir = globals().get('data_dir') or os.path.join('data', dataset)",
    txt,
    count=1
)

tp_path.write_text(patched)
print("Patched train.py to respect overridden data_dir.")
# Out:
# Patched train.py to respect overridden data_dir.

# %%
# === Cell 5 (fixed) ===
import os
from pathlib import Path

os.chdir(REPO_DIR)
# !python train.py
os.chdir("..")
# Out:
# [train.py] Loaded override from /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/out_onegroup/config_override.json
# tokens per iteration will be: 61,440
# /home/STUDENTS/mc1836/miniconda3/envs/torch/lib/python3.11/site-packages/torch/backends/__init__.py:46: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   self.setter(val)
# found vocab_size = 65 (inside /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/data/shakespeare_char/meta.pkl)
# Initializing a new model from scratch
# number of parameters: 12.62M
# num decayed parameter tensors: 18, with 12,681,728 parameters
# num non-decayed parameter tensors: 9, with 4,608 parameters
# using fused AdamW: True
# step 0: train loss 4.2578, val loss 4.2599
# iter 0: loss 4.2453, time 846.15ms, mfu -100.00%
# iter 1: loss 4.1560, time 140.88ms, mfu -100.00%
# iter 2: loss 3.9476, time 144.96ms, mfu -100.00%
# iter 3: loss 3.7480, time 138.53ms, mfu -100.00%
# iter 4: loss 3.5756, time 165.20ms, mfu -100.00%
# iter 5: loss 3.4790, time 155.25ms, mfu 10.00%
# iter 6: loss 3.3699, time 141.73ms, mfu 10.10%
# iter 7: loss 3.3793, time 146.05ms, mfu 10.15%
# iter 8: loss 3.2474, time 150.66ms, mfu 10.17%
# iter 9: loss 3.1838, time 141.60ms, mfu 10.25%
# iter 10: loss 3.2515, time 146.21ms, mfu 10.29%
# iter 11: loss 3.1349, time 148.98ms, mfu 10.30%
# iter 12: loss 3.0105, time 149.01ms, mfu 10.31%
# iter 13: loss 2.9872, time 159.82ms, mfu 10.25%
# iter 14: loss 2.9814, time 143.90ms, mfu 10.31%
# iter 15: loss 2.9300, time 146.76ms, mfu 10.33%
# iter 16: loss 3.0085, time 144.44ms, mfu 10.38%
# iter 17: loss 2.8927, time 147.56ms, mfu 10.39%
# iter 18: loss 2.8569, time 147.86ms, mfu 10.40%
# iter 19: loss 2.8611, time 146.01ms, mfu 10.43%
# iter 20: loss 2.8253, time 145.66ms, mfu 10.45%
# iter 21: loss 2.8282, time 163.44ms, mfu 10.36%
# iter 22: loss 2.7502, time 151.95ms, mfu 10.34%
# iter 23: loss 2.7286, time 155.95ms, mfu 10.30%
# iter 24: loss 2.6792, time 147.67ms, mfu 10.32%
# iter 25: loss 2.6343, time 148.10ms, mfu 10.34%
# iter 26: loss 2.6574, time 149.56ms, mfu 10.35%
# iter 27: loss 2.5766, time 155.75ms, mfu 10.31%
# iter 28: loss 2.6061, time 144.70ms, mfu 10.35%
# iter 29: loss 2.5646, time 149.95ms, mfu 10.35%
# iter 30: loss 2.5780, time 151.99ms, mfu 10.34%
# iter 31: loss 2.5219, time 158.57ms, mfu 10.28%
# iter 32: loss 2.5231, time 139.84ms, mfu 10.37%
# iter 33: loss 2.5970, time 148.51ms, mfu 10.38%
# iter 34: loss 2.5484, time 139.67ms, mfu 10.45%
# iter 35: loss 2.5601, time 149.52ms, mfu 10.44%
# iter 36: loss 2.5507, time 172.86ms, mfu 10.30%
# iter 37: loss 2.5862, time 138.41ms, mfu 10.39%
# iter 38: loss 2.5300, time 154.50ms, mfu 10.36%
# iter 39: loss 2.5044, time 163.97ms, mfu 10.27%
# iter 40: loss 2.5171, time 144.35ms, mfu 10.32%
# iter 41: loss 2.5106, time 144.94ms, mfu 10.36%
# iter 42: loss 2.4531, time 145.94ms, mfu 10.39%
# iter 43: loss 2.5373, time 140.79ms, mfu 10.45%
# iter 44: loss 2.4985, time 151.57ms, mfu 10.43%
# iter 45: loss 2.4930, time 149.89ms, mfu 10.42%
# iter 46: loss 2.5200, time 162.74ms, mfu 10.34%
# iter 47: loss 2.5476, time 147.27ms, mfu 10.36%
# iter 48: loss 2.4475, time 155.50ms, mfu 10.32%
# iter 49: loss 2.4906, time 148.46ms, mfu 10.33%
# step 50: train loss 2.4345, val loss 2.4499
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/out_group3
# iter 50: loss 2.4210, time 685.38ms, mfu 9.53%
# iter 51: loss 2.4155, time 142.82ms, mfu 9.66%
# iter 52: loss 2.4823, time 148.86ms, mfu 9.74%
# iter 53: loss 2.4464, time 142.19ms, mfu 9.86%
# iter 54: loss 2.4293, time 155.26ms, mfu 9.87%
# iter 55: loss 2.4608, time 138.28ms, mfu 10.01%
# iter 56: loss 2.4057, time 147.32ms, mfu 10.06%
# iter 57: loss 2.4433, time 148.70ms, mfu 10.10%
# iter 58: loss 2.4264, time 167.44ms, mfu 10.02%
# iter 59: loss 2.4295, time 146.69ms, mfu 10.07%
# iter 60: loss 2.4297, time 146.53ms, mfu 10.13%
# iter 61: loss 2.4151, time 144.88ms, mfu 10.19%
# iter 62: loss 2.3481, time 150.98ms, mfu 10.20%
# iter 63: loss 2.3632, time 144.47ms, mfu 10.25%
# iter 64: loss 2.4598, time 148.12ms, mfu 10.28%
# iter 65: loss 2.4461, time 145.96ms, mfu 10.31%
# iter 66: loss 2.3741, time 150.09ms, mfu 10.32%
# iter 67: loss 2.4483, time 142.95ms, mfu 10.37%
# iter 68: loss 2.3661, time 144.36ms, mfu 10.41%
# iter 69: loss 2.4084, time 159.70ms, mfu 10.34%
# iter 70: loss 2.3846, time 164.35ms, mfu 10.25%
# iter 71: loss 2.3840, time 139.56ms, mfu 10.34%
# iter 72: loss 2.4047, time 157.56ms, mfu 10.29%
# iter 73: loss 2.3907, time 140.59ms, mfu 10.37%
# iter 74: loss 2.3958, time 149.86ms, mfu 10.37%
# iter 75: loss 2.3270, time 141.27ms, mfu 10.43%
# iter 76: loss 2.3796, time 144.58ms, mfu 10.46%
# iter 77: loss 2.3782, time 140.00ms, mfu 10.52%
# iter 78: loss 2.3003, time 166.10ms, mfu 10.41%
# iter 79: loss 2.3070, time 155.37ms, mfu 10.37%
# iter 80: loss 2.4248, time 144.84ms, mfu 10.40%
# iter 81: loss 2.3709, time 147.24ms, mfu 10.42%
# iter 82: loss 2.2997, time 146.97ms, mfu 10.43%
# iter 83: loss 2.3285, time 147.61ms, mfu 10.44%
# iter 84: loss 2.3279, time 163.78ms, mfu 10.34%
# iter 85: loss 2.3629, time 152.46ms, mfu 10.33%
# iter 86: loss 2.3382, time 145.58ms, mfu 10.36%
# iter 87: loss 2.2740, time 153.42ms, mfu 10.34%
# iter 88: loss 2.2896, time 149.38ms, mfu 10.34%
# iter 89: loss 2.3227, time 146.13ms, mfu 10.37%
# iter 90: loss 2.3350, time 152.38ms, mfu 10.36%
# iter 91: loss 2.2725, time 150.41ms, mfu 10.35%
# iter 92: loss 2.3310, time 149.07ms, mfu 10.36%
# iter 93: loss 2.3050, time 142.12ms, mfu 10.42%
# iter 94: loss 2.3090, time 154.92ms, mfu 10.38%
# iter 95: loss 2.3484, time 138.20ms, mfu 10.46%
# iter 96: loss 2.3214, time 142.54ms, mfu 10.51%
# iter 97: loss 2.3208, time 145.65ms, mfu 10.52%
# iter 98: loss 2.3132, time 144.15ms, mfu 10.55%
# iter 99: loss 2.2906, time 137.86ms, mfu 10.62%
# step 100: train loss 2.2231, val loss 2.2564
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/out_group3
# iter 100: loss 2.2883, time 770.51ms, mfu 9.76%
# iter 101: loss 2.2383, time 140.62ms, mfu 9.89%
# iter 102: loss 2.2683, time 154.30ms, mfu 9.91%
# iter 103: loss 2.2033, time 139.20ms, mfu 10.03%
# iter 104: loss 2.2199, time 144.60ms, mfu 10.10%
# iter 105: loss 2.2330, time 146.91ms, mfu 10.15%
# iter 106: loss 2.2862, time 153.02ms, mfu 10.15%
# iter 107: loss 2.2404, time 137.88ms, mfu 10.26%
# iter 108: loss 2.2912, time 152.95ms, mfu 10.25%
# iter 109: loss 2.2513, time 143.07ms, mfu 10.31%
# iter 110: loss 2.2140, time 142.13ms, mfu 10.37%
# iter 111: loss 2.3149, time 143.15ms, mfu 10.42%
# iter 112: loss 2.2180, time 145.16ms, mfu 10.45%
# iter 113: loss 2.2229, time 141.22ms, mfu 10.50%
# iter 114: loss 2.3082, time 149.27ms, mfu 10.49%
# iter 115: loss 2.3066, time 143.94ms, mfu 10.52%
# iter 116: loss 2.2596, time 140.80ms, mfu 10.57%
# iter 117: loss 2.1873, time 147.40ms, mfu 10.57%
# iter 118: loss 2.1990, time 153.17ms, mfu 10.53%
# iter 119: loss 2.2467, time 145.45ms, mfu 10.54%
# iter 120: loss 2.1115, time 139.75ms, mfu 10.60%
# iter 121: loss 2.1589, time 153.20ms, mfu 10.55%
# iter 122: loss 2.0982, time 139.31ms, mfu 10.61%
# iter 123: loss 2.2033, time 143.23ms, mfu 10.64%
# iter 124: loss 2.1245, time 138.54ms, mfu 10.69%
# iter 125: loss 2.1291, time 138.50ms, mfu 10.75%
# iter 126: loss 2.1558, time 135.54ms, mfu 10.82%
# iter 127: loss 2.2168, time 140.92ms, mfu 10.84%
# iter 128: loss 2.1957, time 146.91ms, mfu 10.81%
# iter 129: loss 2.0814, time 147.49ms, mfu 10.78%
# iter 130: loss 2.1743, time 148.06ms, mfu 10.75%
# iter 131: loss 2.1597, time 146.02ms, mfu 10.74%
# iter 132: loss 2.1014, time 141.01ms, mfu 10.77%
# iter 133: loss 2.1350, time 149.21ms, mfu 10.73%
# iter 134: loss 2.0958, time 145.95ms, mfu 10.72%
# iter 135: loss 2.1265, time 145.97ms, mfu 10.72%
# iter 136: loss 2.1008, time 144.89ms, mfu 10.72%
# iter 137: loss 2.1193, time 145.36ms, mfu 10.71%
# iter 138: loss 2.0462, time 150.72ms, mfu 10.67%
# iter 139: loss 2.0719, time 145.94ms, mfu 10.67%
# iter 140: loss 2.0641, time 155.56ms, mfu 10.60%
# iter 141: loss 2.0440, time 143.53ms, mfu 10.62%
# iter 142: loss 1.9822, time 146.36ms, mfu 10.62%
# iter 143: loss 2.0398, time 148.64ms, mfu 10.60%
# iter 144: loss 2.1068, time 147.44ms, mfu 10.60%
# iter 145: loss 2.0335, time 143.53ms, mfu 10.62%
# iter 146: loss 2.0679, time 146.80ms, mfu 10.62%
# iter 147: loss 2.0715, time 151.07ms, mfu 10.58%
# iter 148: loss 2.0953, time 141.45ms, mfu 10.62%
# iter 149: loss 1.9954, time 151.32ms, mfu 10.59%
# step 150: train loss 1.9624, val loss 2.0536
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/out_group3
# iter 150: loss 2.1213, time 772.32ms, mfu 9.73%
# iter 151: loss 2.0728, time 143.12ms, mfu 9.84%
# iter 152: loss 2.0743, time 153.19ms, mfu 9.87%
# iter 153: loss 1.9696, time 138.97ms, mfu 10.00%
# iter 154: loss 1.9863, time 151.35ms, mfu 10.03%
# iter 155: loss 2.0291, time 151.56ms, mfu 10.05%
# iter 156: loss 1.9504, time 155.32ms, mfu 10.04%
# iter 157: loss 2.0282, time 144.12ms, mfu 10.12%
# iter 158: loss 1.9577, time 146.51ms, mfu 10.17%
# iter 159: loss 1.9963, time 143.52ms, mfu 10.23%
# iter 160: loss 2.0694, time 147.90ms, mfu 10.26%
# iter 161: loss 1.9566, time 157.01ms, mfu 10.22%
# iter 162: loss 1.9360, time 138.00ms, mfu 10.33%
# iter 163: loss 2.0080, time 159.11ms, mfu 10.27%
# iter 164: loss 1.9312, time 149.19ms, mfu 10.28%
# iter 165: loss 1.9473, time 146.15ms, mfu 10.32%
# iter 166: loss 1.8939, time 144.67ms, mfu 10.36%
# iter 167: loss 1.9962, time 143.36ms, mfu 10.41%
# iter 168: loss 1.9983, time 152.24ms, mfu 10.39%
# iter 169: loss 1.9582, time 146.22ms, mfu 10.41%
# iter 170: loss 1.9013, time 158.63ms, mfu 10.35%
# iter 171: loss 1.8914, time 142.63ms, mfu 10.40%
# iter 172: loss 1.9236, time 147.81ms, mfu 10.41%
# iter 173: loss 1.8649, time 142.54ms, mfu 10.46%
# iter 174: loss 1.8929, time 154.82ms, mfu 10.42%
# iter 175: loss 1.9033, time 142.69ms, mfu 10.46%
# iter 176: loss 1.9153, time 146.56ms, mfu 10.48%
# iter 177: loss 1.9395, time 152.02ms, mfu 10.45%
# iter 178: loss 1.8974, time 143.20ms, mfu 10.49%
# iter 179: loss 1.9551, time 148.16ms, mfu 10.49%
# iter 180: loss 1.8291, time 146.25ms, mfu 10.50%
# iter 181: loss 1.8726, time 142.06ms, mfu 10.55%
# iter 182: loss 1.7720, time 148.60ms, mfu 10.54%
# iter 183: loss 1.8936, time 150.74ms, mfu 10.51%
# iter 184: loss 1.8245, time 150.57ms, mfu 10.49%
# iter 185: loss 1.9126, time 143.73ms, mfu 10.52%
# iter 186: loss 1.8673, time 150.05ms, mfu 10.51%
# iter 187: loss 1.9177, time 153.46ms, mfu 10.47%
# iter 188: loss 1.8513, time 140.31ms, mfu 10.53%
# iter 189: loss 1.8790, time 149.60ms, mfu 10.51%
# iter 190: loss 1.9402, time 147.67ms, mfu 10.51%
# iter 191: loss 1.8518, time 144.25ms, mfu 10.54%
# iter 192: loss 1.8397, time 146.99ms, mfu 10.54%
# iter 193: loss 1.8807, time 152.93ms, mfu 10.50%
# iter 194: loss 1.9263, time 144.58ms, mfu 10.53%
# iter 195: loss 1.8010, time 150.99ms, mfu 10.50%
# iter 196: loss 1.8460, time 144.05ms, mfu 10.53%
# iter 197: loss 1.9104, time 147.20ms, mfu 10.53%
# iter 198: loss 1.8612, time 152.69ms, mfu 10.50%
# iter 199: loss 1.8007, time 145.17ms, mfu 10.52%
# step 200: train loss 1.7606, val loss 1.9203
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/out_group3
# iter 200: loss 1.8703, time 801.13ms, mfu 9.66%
# iter 201: loss 1.8450, time 143.06ms, mfu 9.78%
# iter 202: loss 1.7954, time 147.56ms, mfu 9.85%
# iter 203: loss 1.8982, time 152.06ms, mfu 9.89%
# iter 204: loss 1.8317, time 140.72ms, mfu 10.00%
# iter 205: loss 1.7987, time 148.97ms, mfu 10.05%
# iter 206: loss 1.8471, time 149.22ms, mfu 10.08%
# iter 207: loss 1.8334, time 149.79ms, mfu 10.11%
# iter 208: loss 1.7724, time 156.68ms, mfu 10.09%
# iter 209: loss 1.7851, time 147.67ms, mfu 10.13%
# iter 210: loss 1.7141, time 147.73ms, mfu 10.17%
# iter 211: loss 1.7396, time 145.39ms, mfu 10.22%
# iter 212: loss 1.8443, time 143.69ms, mfu 10.28%
# iter 213: loss 1.7043, time 146.97ms, mfu 10.31%
# iter 214: loss 1.7722, time 146.78ms, mfu 10.34%
# iter 215: loss 1.8168, time 151.20ms, mfu 10.33%
# iter 216: loss 1.7726, time 151.22ms, mfu 10.32%
# iter 217: loss 1.7031, time 158.88ms, mfu 10.27%
# iter 218: loss 1.6931, time 179.67ms, mfu 10.11%
# iter 219: loss 1.7071, time 167.38ms, mfu 10.02%
# iter 220: loss 1.7430, time 199.76ms, mfu 9.80%
# iter 221: loss 1.7790, time 162.25ms, mfu 9.78%
# iter 222: loss 1.7748, time 182.24ms, mfu 9.65%
# iter 223: loss 1.8182, time 147.94ms, mfu 9.74%
# iter 224: loss 1.6766, time 180.89ms, mfu 9.62%
# iter 225: loss 1.7358, time 188.79ms, mfu 9.48%
# iter 226: loss 1.7238, time 161.51ms, mfu 9.50%
# iter 227: loss 1.7856, time 148.91ms, mfu 9.59%
# iter 228: loss 1.8123, time 158.31ms, mfu 9.61%
# iter 229: loss 1.7577, time 391.05ms, mfu 9.05%
# iter 230: loss 1.7565, time 252.71ms, mfu 8.76%
# iter 231: loss 1.6119, time 182.54ms, mfu 8.73%
# iter 232: loss 1.7064, time 153.86ms, mfu 8.87%
# iter 233: loss 1.6614, time 153.49ms, mfu 8.99%
# iter 234: loss 1.6968, time 177.43ms, mfu 8.97%
# iter 235: loss 1.6780, time 156.55ms, mfu 9.06%
# iter 236: loss 1.7132, time 158.21ms, mfu 9.14%
# iter 237: loss 1.6891, time 158.54ms, mfu 9.21%
# iter 238: loss 1.7731, time 155.57ms, mfu 9.28%
# iter 239: loss 1.7067, time 159.35ms, mfu 9.33%
# iter 240: loss 1.6398, time 158.79ms, mfu 9.37%
# iter 241: loss 1.7110, time 162.24ms, mfu 9.39%
# iter 242: loss 1.7252, time 172.84ms, mfu 9.35%
# iter 243: loss 1.6681, time 168.66ms, mfu 9.34%
# iter 244: loss 1.7095, time 163.29ms, mfu 9.36%
# iter 245: loss 1.7035, time 240.19ms, mfu 9.07%
# iter 246: loss 1.7177, time 470.93ms, mfu 8.49%
# iter 247: loss 1.6983, time 463.54ms, mfu 7.98%
# iter 248: loss 1.6440, time 225.64ms, mfu 7.87%
# iter 249: loss 1.6936, time 167.98ms, mfu 8.01%
# step 250: train loss 1.6282, val loss 1.7988
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/out_group3
# iter 250: loss 1.7662, time 801.63ms, mfu 7.40%
# iter 251: loss 1.7036, time 170.62ms, mfu 7.57%
# iter 252: loss 1.6488, time 169.19ms, mfu 7.73%
# iter 253: loss 1.6564, time 171.31ms, mfu 7.86%
# iter 254: loss 1.6343, time 166.35ms, mfu 8.01%
# iter 255: loss 1.7054, time 166.17ms, mfu 8.14%
# iter 256: loss 1.5824, time 166.84ms, mfu 8.26%
# iter 257: loss 1.6943, time 168.46ms, mfu 8.36%
# iter 258: loss 1.6592, time 171.97ms, mfu 8.42%
# iter 259: loss 1.7719, time 171.83ms, mfu 8.49%
# iter 260: loss 1.6119, time 170.37ms, mfu 8.55%
# iter 261: loss 1.6173, time 167.94ms, mfu 8.62%
# iter 262: loss 1.7441, time 177.30ms, mfu 8.63%
# iter 263: loss 1.6935, time 176.40ms, mfu 8.65%
# iter 264: loss 1.6746, time 169.79ms, mfu 8.70%
# iter 265: loss 1.8556, time 173.53ms, mfu 8.72%
# iter 266: loss 1.6802, time 196.24ms, mfu 8.64%
# iter 267: loss 1.6687, time 223.45ms, mfu 8.47%
# iter 268: loss 1.5902, time 189.98ms, mfu 8.44%
# iter 269: loss 1.6975, time 200.98ms, mfu 8.37%
# iter 270: loss 1.7208, time 195.25ms, mfu 8.33%
# iter 271: loss 1.6614, time 208.94ms, mfu 8.24%
# iter 272: loss 1.6916, time 199.23ms, mfu 8.20%
# iter 273: loss 1.7376, time 221.13ms, mfu 8.08%
# iter 274: loss 1.6410, time 237.48ms, mfu 7.93%
# iter 275: loss 1.6498, time 256.22ms, mfu 7.74%
# iter 276: loss 1.6029, time 392.44ms, mfu 7.36%
# iter 277: loss 1.6344, time 381.91ms, mfu 7.03%
# iter 278: loss 1.6975, time 365.21ms, mfu 6.75%
# iter 279: loss 1.6732, time 345.22ms, mfu 6.53%
# iter 280: loss 1.5890, time 212.09ms, mfu 6.61%
# iter 281: loss 1.6640, time 246.82ms, mfu 6.58%
# iter 282: loss 1.5913, time 197.22ms, mfu 6.71%
# iter 283: loss 1.6286, time 196.70ms, mfu 6.83%
# iter 284: loss 1.6095, time 172.55ms, mfu 7.04%
# iter 285: loss 1.5574, time 282.48ms, mfu 6.89%
# iter 286: loss 1.6268, time 598.96ms, mfu 6.46%
# iter 287: loss 1.5617, time 514.69ms, mfu 6.11%
# iter 288: loss 1.6502, time 398.14ms, mfu 5.89%
# iter 289: loss 1.7045, time 245.89ms, mfu 5.94%
# iter 290: loss 1.6544, time 266.51ms, mfu 5.92%
# iter 291: loss 1.6436, time 189.84ms, mfu 6.15%
# iter 292: loss 1.7425, time 319.04ms, mfu 6.02%
# iter 293: loss 1.6652, time 531.00ms, mfu 5.71%
# iter 294: loss 1.6107, time 338.94ms, mfu 5.60%
# iter 295: loss 1.5763, time 209.74ms, mfu 5.78%
# iter 296: loss 1.5737, time 356.99ms, mfu 5.64%
# iter 297: loss 1.5950, time 369.62ms, mfu 5.49%
# iter 298: loss 1.6431, time 227.34ms, mfu 5.63%
# iter 299: loss 1.6098, time 216.65ms, mfu 5.78%
# step 300: train loss 1.5276, val loss 1.7159
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/out_group3
# iter 300: loss 1.5641, time 931.36ms, mfu 5.37%
# iter 301: loss 1.6222, time 225.85ms, mfu 5.52%
# iter 302: loss 1.5824, time 310.42ms, mfu 5.47%
# iter 303: loss 1.6377, time 477.46ms, mfu 5.25%
# iter 304: loss 1.5663, time 376.48ms, mfu 5.14%
# iter 305: loss 1.6168, time 246.02ms, mfu 5.25%
# iter 306: loss 1.6404, time 237.24ms, mfu 5.38%
# iter 307: loss 1.5607, time 234.73ms, mfu 5.51%
# iter 308: loss 1.5901, time 336.50ms, mfu 5.42%
# iter 309: loss 1.5226, time 411.53ms, mfu 5.25%
# iter 310: loss 1.6438, time 379.29ms, mfu 5.14%
# iter 311: loss 1.6453, time 294.24ms, mfu 5.15%
# iter 312: loss 1.6008, time 483.58ms, mfu 4.96%
# iter 313: loss 1.5947, time 444.83ms, mfu 4.81%
# iter 314: loss 1.6602, time 283.42ms, mfu 4.88%
# iter 315: loss 1.6659, time 231.23ms, mfu 5.06%
# iter 316: loss 1.6002, time 292.18ms, mfu 5.09%
# iter 317: loss 1.5853, time 435.20ms, mfu 4.93%
# iter 318: loss 1.5793, time 204.52ms, mfu 5.20%
# iter 319: loss 1.5251, time 227.11ms, mfu 5.36%
# iter 320: loss 1.5735, time 397.77ms, mfu 5.22%
# iter 321: loss 1.6292, time 214.49ms, mfu 5.42%
# iter 322: loss 1.6378, time 236.83ms, mfu 5.53%
# iter 323: loss 1.5984, time 247.95ms, mfu 5.61%
# iter 324: loss 1.6677, time 509.36ms, mfu 5.35%
# iter 325: loss 1.6084, time 272.75ms, mfu 5.39%
# iter 326: loss 1.6588, time 242.26ms, mfu 5.49%
# iter 327: loss 1.6478, time 222.98ms, mfu 5.64%
# iter 328: loss 1.5646, time 246.02ms, mfu 5.70%
# iter 329: loss 1.4771, time 224.37ms, mfu 5.83%
# iter 330: loss 1.5551, time 315.45ms, mfu 5.74%
# iter 331: loss 1.5549, time 440.75ms, mfu 5.51%
# iter 332: loss 1.6235, time 497.95ms, mfu 5.27%
# iter 333: loss 1.5638, time 302.17ms, mfu 5.26%
# iter 334: loss 1.4837, time 372.23ms, mfu 5.15%
# iter 335: loss 1.5632, time 448.78ms, mfu 4.98%
# iter 336: loss 1.6353, time 399.09ms, mfu 4.87%
# iter 337: loss 1.5057, time 351.76ms, mfu 4.83%
# iter 338: loss 1.5385, time 210.38ms, mfu 5.08%
# iter 339: loss 1.5316, time 214.24ms, mfu 5.30%
# iter 340: loss 1.6111, time 325.46ms, mfu 5.25%
# iter 341: loss 1.6045, time 472.17ms, mfu 5.05%
# iter 342: loss 1.5721, time 442.85ms, mfu 4.90%
# iter 343: loss 1.5810, time 276.98ms, mfu 4.97%
# iter 344: loss 1.5573, time 223.81ms, mfu 5.17%
# iter 345: loss 1.5778, time 223.89ms, mfu 5.34%
# iter 346: loss 1.5130, time 217.03ms, mfu 5.52%
# iter 347: loss 1.6014, time 269.36ms, mfu 5.55%
# iter 348: loss 1.5356, time 390.96ms, mfu 5.39%
# iter 349: loss 1.4964, time 317.69ms, mfu 5.34%
# step 350: train loss 1.4784, val loss 1.6721
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/out_group3
# iter 350: loss 1.5426, time 1524.78ms, mfu 4.91%
# iter 351: loss 1.5614, time 414.73ms, mfu 4.79%
# iter 352: loss 1.4770, time 347.26ms, mfu 4.76%
# iter 353: loss 1.5991, time 244.68ms, mfu 4.92%
# iter 354: loss 1.6519, time 268.16ms, mfu 5.01%
# iter 355: loss 1.6204, time 485.25ms, mfu 4.83%
# iter 356: loss 1.5655, time 524.14ms, mfu 4.64%
# iter 357: loss 1.4855, time 358.92ms, mfu 4.61%
# iter 358: loss 1.5312, time 208.89ms, mfu 4.89%
# iter 359: loss 1.5260, time 288.04ms, mfu 4.94%
# iter 360: loss 1.4889, time 306.67ms, mfu 4.95%
# iter 361: loss 1.5435, time 406.38ms, mfu 4.84%
# iter 362: loss 1.5331, time 369.07ms, mfu 4.78%
# iter 363: loss 1.5758, time 343.12ms, mfu 4.75%
# iter 364: loss 1.4822, time 387.23ms, mfu 4.68%
# iter 365: loss 1.4951, time 232.28ms, mfu 4.88%
# iter 366: loss 1.4967, time 202.06ms, mfu 5.16%
# iter 367: loss 1.5464, time 253.55ms, mfu 5.26%
# iter 368: loss 1.5279, time 323.18ms, mfu 5.21%
# iter 369: loss 1.4396, time 320.65ms, mfu 5.17%
# iter 370: loss 1.5841, time 232.59ms, mfu 5.32%
# iter 371: loss 1.4871, time 220.67ms, mfu 5.50%
# iter 372: loss 1.6129, time 260.44ms, mfu 5.54%
# iter 373: loss 1.4823, time 264.08ms, mfu 5.58%
# iter 374: loss 1.6279, time 251.53ms, mfu 5.64%
# iter 375: loss 1.4403, time 344.09ms, mfu 5.52%
# iter 376: loss 1.5146, time 481.39ms, mfu 5.29%
# iter 377: loss 1.5642, time 443.70ms, mfu 5.11%
# iter 378: loss 1.5970, time 262.95ms, mfu 5.19%
# iter 379: loss 1.5506, time 217.45ms, mfu 5.39%
# iter 380: loss 1.5074, time 321.43ms, mfu 5.33%
# iter 381: loss 1.5386, time 279.23ms, mfu 5.36%
# iter 382: loss 1.5542, time 222.40ms, mfu 5.52%
# iter 383: loss 1.5696, time 318.45ms, mfu 5.45%
# iter 384: loss 1.4518, time 477.18ms, mfu 5.23%
# iter 385: loss 1.4948, time 557.65ms, mfu 4.99%
# iter 386: loss 1.5753, time 531.96ms, mfu 4.78%
# iter 387: loss 1.6129, time 277.56ms, mfu 4.86%
# iter 388: loss 1.4323, time 223.58ms, mfu 5.07%
# iter 389: loss 1.5595, time 231.54ms, mfu 5.24%
# iter 390: loss 1.5343, time 225.40ms, mfu 5.40%
# iter 391: loss 1.5501, time 209.62ms, mfu 5.60%
# iter 392: loss 1.5059, time 235.30ms, mfu 5.70%
# iter 393: loss 1.5036, time 254.68ms, mfu 5.74%
# iter 394: loss 1.4879, time 239.88ms, mfu 5.81%
# iter 395: loss 1.5757, time 251.17ms, mfu 5.85%
# iter 396: loss 1.6208, time 239.19ms, mfu 5.92%
# iter 397: loss 1.5574, time 352.85ms, mfu 5.76%
# iter 398: loss 1.5022, time 465.13ms, mfu 5.52%
# iter 399: loss 1.4985, time 245.12ms, mfu 5.60%
# step 400: train loss 1.4441, val loss 1.6369
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/out_group3
# iter 400: loss 1.4798, time 1762.16ms, mfu 5.13%
# iter 401: loss 1.5680, time 352.69ms, mfu 5.06%
# iter 402: loss 1.5815, time 257.90ms, mfu 5.15%
# iter 403: loss 1.6167, time 217.47ms, mfu 5.35%
# iter 404: loss 1.5204, time 401.28ms, mfu 5.21%
# iter 405: loss 1.6041, time 206.75ms, mfu 5.44%
# iter 406: loss 1.6044, time 317.85ms, mfu 5.38%
# iter 407: loss 1.5146, time 424.39ms, mfu 5.21%
# iter 408: loss 1.5685, time 441.97ms, mfu 5.04%
# iter 409: loss 1.5291, time 233.21ms, mfu 5.20%
# iter 410: loss 1.5455, time 238.17ms, mfu 5.33%
# iter 411: loss 1.5104, time 216.81ms, mfu 5.52%
# iter 412: loss 1.4045, time 253.71ms, mfu 5.58%
# iter 413: loss 1.4348, time 232.40ms, mfu 5.69%
# iter 414: loss 1.5600, time 250.91ms, mfu 5.74%
# iter 415: loss 1.4864, time 247.62ms, mfu 5.79%
# iter 416: loss 1.5450, time 363.76ms, mfu 5.64%
# iter 417: loss 1.5602, time 489.51ms, mfu 5.39%
# iter 418: loss 1.4830, time 411.84ms, mfu 5.23%
# iter 419: loss 1.4431, time 370.08ms, mfu 5.13%
# iter 420: loss 1.4961, time 316.18ms, mfu 5.11%
# iter 421: loss 1.4738, time 332.02ms, mfu 5.06%
# iter 422: loss 1.5634, time 263.62ms, mfu 5.15%
# iter 423: loss 1.5322, time 391.94ms, mfu 5.03%
# iter 424: loss 1.4797, time 212.58ms, mfu 5.26%
# iter 425: loss 1.6299, time 380.95ms, mfu 5.14%
# iter 426: loss 1.5819, time 242.40ms, mfu 5.26%
# iter 427: loss 1.4767, time 381.34ms, mfu 5.15%
# iter 428: loss 1.4850, time 237.88ms, mfu 5.28%
# iter 429: loss 1.4642, time 243.99ms, mfu 5.39%
# iter 430: loss 1.4849, time 264.10ms, mfu 5.44%
# iter 431: loss 1.4931, time 374.60ms, mfu 5.31%
# iter 432: loss 1.5375, time 478.55ms, mfu 5.10%
# iter 433: loss 1.5369, time 399.32ms, mfu 4.98%
# iter 434: loss 1.4372, time 282.55ms, mfu 5.03%
# iter 435: loss 1.6207, time 276.44ms, mfu 5.09%
# iter 436: loss 1.5608, time 261.39ms, mfu 5.18%
# iter 437: loss 1.6021, time 332.45ms, mfu 5.13%
# iter 438: loss 1.5051, time 225.88ms, mfu 5.30%
# iter 439: loss 1.5272, time 228.06ms, mfu 5.45%
# iter 440: loss 1.5040, time 515.60ms, mfu 5.21%
# iter 441: loss 1.4831, time 424.87ms, mfu 5.05%
# iter 442: loss 1.5967, time 210.87ms, mfu 5.28%
# iter 443: loss 1.5425, time 237.77ms, mfu 5.41%
# iter 444: loss 1.4580, time 237.80ms, mfu 5.52%
# iter 445: loss 1.5799, time 229.56ms, mfu 5.65%
# iter 446: loss 1.5466, time 299.03ms, mfu 5.60%
# iter 447: loss 1.5272, time 391.98ms, mfu 5.44%
# iter 448: loss 1.5039, time 303.95ms, mfu 5.40%
# iter 449: loss 1.5735, time 343.38ms, mfu 5.32%
# step 450: train loss 1.4171, val loss 1.6236
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/out_group3
# iter 450: loss 1.5900, time 1326.30ms, mfu 4.90%
# iter 451: loss 1.5003, time 428.96ms, mfu 4.77%
# iter 452: loss 1.5778, time 469.99ms, mfu 4.63%
# iter 453: loss 1.4670, time 271.72ms, mfu 4.74%
# iter 454: loss 1.5592, time 323.22ms, mfu 4.74%
# iter 455: loss 1.4882, time 212.57ms, mfu 5.00%
# iter 456: loss 1.6040, time 374.47ms, mfu 4.91%
# iter 457: loss 1.4743, time 562.43ms, mfu 4.70%
# iter 458: loss 1.5560, time 353.68ms, mfu 4.67%
# iter 459: loss 1.4703, time 209.09ms, mfu 4.94%
# iter 460: loss 1.4605, time 234.01ms, mfu 5.11%
# iter 461: loss 1.3602, time 199.29ms, mfu 5.38%
# iter 462: loss 1.5383, time 275.14ms, mfu 5.41%
# iter 463: loss 1.5295, time 220.91ms, mfu 5.57%
# iter 464: loss 1.5325, time 234.59ms, mfu 5.67%
# iter 465: loss 1.5280, time 285.95ms, mfu 5.65%
# iter 466: loss 1.5157, time 338.86ms, mfu 5.54%
# iter 467: loss 1.4939, time 250.34ms, mfu 5.61%
# iter 468: loss 1.5765, time 283.62ms, mfu 5.60%
# iter 469: loss 1.5392, time 233.01ms, mfu 5.70%
# iter 470: loss 1.4861, time 289.79ms, mfu 5.67%
# iter 471: loss 1.5612, time 486.58ms, mfu 5.42%
# iter 472: loss 1.5139, time 587.16ms, mfu 5.14%
# iter 473: loss 1.5308, time 289.70ms, mfu 5.17%
# iter 474: loss 1.6290, time 240.38ms, mfu 5.30%
# iter 475: loss 1.5207, time 232.04ms, mfu 5.43%
# iter 476: loss 1.5493, time 217.02ms, mfu 5.61%
# iter 477: loss 1.5667, time 351.89ms, mfu 5.49%
# iter 478: loss 1.4406, time 492.78ms, mfu 5.25%
# iter 479: loss 1.4775, time 516.61ms, mfu 5.03%
# iter 480: loss 1.4699, time 432.39ms, mfu 4.89%
# iter 481: loss 1.5599, time 227.23ms, mfu 5.08%
# iter 482: loss 1.5186, time 220.65ms, mfu 5.28%
# iter 483: loss 1.3849, time 218.44ms, mfu 5.46%
# iter 484: loss 1.4033, time 246.66ms, mfu 5.54%
# iter 485: loss 1.5150, time 240.07ms, mfu 5.64%
# iter 486: loss 1.4750, time 251.04ms, mfu 5.69%
# iter 487: loss 1.4601, time 264.02ms, mfu 5.71%
# iter 488: loss 1.5003, time 356.63ms, mfu 5.57%
# iter 489: loss 1.5153, time 318.12ms, mfu 5.51%
# iter 490: loss 1.4973, time 216.81ms, mfu 5.67%
# iter 491: loss 1.5371, time 369.20ms, mfu 5.52%
# iter 492: loss 1.5858, time 214.45ms, mfu 5.70%
# iter 493: loss 1.4490, time 281.84ms, mfu 5.68%
# iter 494: loss 1.4043, time 487.98ms, mfu 5.43%
# iter 495: loss 1.4669, time 292.24ms, mfu 5.42%
# iter 496: loss 1.4966, time 389.10ms, mfu 5.27%
# iter 497: loss 1.4461, time 457.89ms, mfu 5.09%
# iter 498: loss 1.4972, time 546.35ms, mfu 4.86%
# iter 499: loss 1.5741, time 210.19ms, mfu 5.11%
# step 500: train loss 1.4088, val loss 1.6065
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/out_group3
# iter 500: loss 1.5150, time 2138.71ms, mfu 4.68%

# %%
# === Cell 6: plot curves (train, val, gap) ===
import os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

log_csv = str(Path(OUT_DIR) / "loss_log.csv")
if not os.path.exists(log_csv):
    raise SystemExit("No loss_log.csv yet. Let training run (eval_interval small helps).")

df = pd.read_csv(log_csv)
if df.empty:
    raise SystemExit("loss_log.csv is empty.")

# --- Training curve ---
dft = df[df["split"] == "train"].sort_values("iter")
if not dft.empty:
    plt.figure()
    plt.plot(dft["iter"], dft["loss"])
    plt.title("Training Loss Curve")
    plt.xlabel("Iteration")
    plt.ylabel("Loss")
    plt.show()
else:
    print("No 'train' rows in loss_log.csv")

# --- Validation curve ---
dfv = df[df["split"] == "val"].sort_values("iter")
if not dfv.empty:
    plt.figure()
    plt.plot(dfv["iter"], dfv["loss"])
    plt.title("Validation Loss Curve")
    plt.xlabel("Iteration")
    plt.ylabel("Loss")
    plt.show()
else:
    print("No 'val' rows yet (run longer or lower eval_interval).")

# --- Train–Val Gap (nearest-neighbor align val to the latest <= train iter) ---
if not dft.empty and not dfv.empty:
    t_iters = dft["iter"].to_numpy()
    t_loss  = dft["loss"].to_numpy()

    aligned = []
    for _, r in dfv.iterrows():
        v_it, v_loss = int(r["iter"]), float(r["loss"])
        # index of latest train iter <= v_it; fallback to first train iter
        idx = np.searchsorted(t_iters, v_it, side="right") - 1
        if idx < 0:
            idx = 0
        aligned.append((v_it, v_loss - t_loss[idx]))

    adf = pd.DataFrame(aligned, columns=["iter", "gap"])
    plt.figure()
    plt.plot(adf["iter"], adf["gap"])
    plt.title("Train–Val Loss Gap (Overfitting Indicator)")
    plt.xlabel("Iteration (val)")
    plt.ylabel("Val - Train")
    plt.show()
else:
    print("Not enough data for gap curve yet (need both train and val).")

# %%
# === Cell 7: params & memory from last checkpoint ===
import os, importlib.util, torch
from pathlib import Path

CKPT = str(Path(OUT_DIR) / "ckpt.pt")
if not os.path.exists(CKPT):
    raise SystemExit("No checkpoint found. Let training run past the first eval (Cell 3 sets always_save_checkpoint=True).")

# import model module
spec = importlib.util.spec_from_file_location("nanogpt_model", MODEL_PY)
mod  = importlib.util.module_from_spec(spec)
spec.loader.exec_module(mod)

ckpt = torch.load(CKPT, map_location="cpu")
model_args = ckpt.get("model_args") or ckpt.get("config") or {}
gcfg = mod.GPTConfig(**model_args)
model = mod.GPT(gcfg)
model.load_state_dict(ckpt["model"], strict=False)

# counts & memory
n_params = sum(p.numel() for p in model.parameters())
def human(b): 
    return f"{b/1024/1024:.2f} MB" if b < 1024**3 else f"{b/1024/1024/1024:.2f} GB"
model_mem = n_params * 2           # bf16/fp16 weights ~2 bytes each
opt_states_same = n_params * 2 * 2 # two moments at same dtype
opt_states_fp32 = n_params * 2 * 4 # conservative fp32 optimizer states

print("Model args:", model_args)
print(f"Total parameters: {n_params:,}")
print("Model weights (fp16/bf16):", human(model_mem))
print("Optimizer states (same):  ", human(opt_states_same))
print("Optimizer states (fp32):  ", human(opt_states_fp32))
print("Total optimistic:", human(model_mem + opt_states_same))
print("Total conservative:", human(model_mem + opt_states_fp32))
# Out:
# number of parameters: 12.62M
# Model args: {'n_layer': 4, 'n_head': 8, 'n_embd': 512, 'block_size': 128, 'bias': False, 'vocab_size': 65, 'dropout': 0.1}
# Total parameters: 12,686,336
# Model weights (fp16/bf16): 24.20 MB
# Optimizer states (same):   48.39 MB
# Optimizer states (fp32):   96.79 MB
# Total optimistic: 72.59 MB
# Total conservative: 120.99 MB

# %%
# === Cell 8a: ensure checkpoint exists (create one quickly if missing) ===
import os, json, time, shlex
from pathlib import Path

repo = Path(REPO_DIR)
out_dir = Path(OUT_DIR)
ckpt = out_dir / "ckpt.pt"

if ckpt.exists():
    print("✅ Found checkpoint:", ckpt)
else:
    print("ℹ️ No checkpoint found at", ckpt)
    # Temporarily write a minimal override that forces an immediate eval+save and exits.
    temp_cfg = {
        "out_dir": str(out_dir),
        "data_dir": str(Path(DATA_DIR)),
        "eval_only": True,
        "always_save_checkpoint": True,
        # keep a tiny model so it's quick if the repo insists on building the net
        "block_size": 128, "n_layer": 2, "n_head": 2, "n_embd": 128,
        "batch_size": 8, "eval_iters": 10, "compile": False
    }
    tmp_override = out_dir / "config_override.json"
    tmp_override.write_text(json.dumps(temp_cfg, indent=2))
    print("Wrote temporary override →", tmp_override)

    # Run a one-off eval to save ckpt.pt
    cwd = os.getcwd()
    os.chdir(str(repo))
    ret = os.system("python train.py")
    os.chdir(cwd)

    if ckpt.exists():
        print("✅ Created checkpoint:", ckpt)
    else:
        raise SystemExit("❌ Could not create a checkpoint. Run training a bit (lower eval_interval) and retry.")
# Out:
# ✅ Found checkpoint: /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/out_onegroup/ckpt.pt

# %%
# === Cell 8b (safe): direct sampler with clamped top-k ===
import os, pickle, torch, time, importlib.util
from pathlib import Path

repo = Path(REPO_DIR)
out_dir = Path(OUT_DIR)
data_dir = Path(DATA_DIR)
ckpt_path = out_dir / "ckpt.pt"
meta_path = data_dir / "meta.pkl"
assert ckpt_path.exists(), f"Checkpoint not found: {ckpt_path}"
assert meta_path.exists(), f"meta.pkl not found: {meta_path}"

with open(meta_path, "rb") as f:
    meta = pickle.load(f)
stoi, itos = meta["stoi"], meta["itos"]

def encode(s): return [stoi[c] for c in s if c in stoi]
def decode(ids): return "".join(itos[i] for i in ids)

spec = importlib.util.spec_from_file_location("nanogpt_model", str(repo / "model.py"))
mod  = importlib.util.module_from_spec(spec); spec.loader.exec_module(mod)

ckpt = torch.load(str(ckpt_path), map_location="cpu")
model_args = ckpt.get("model_args") or ckpt.get("config") or {}
model = mod.GPT(mod.GPTConfig(**model_args))
model.load_state_dict(ckpt["model"], strict=False)
model.eval()

PROMPT = "In a quiet lab, the scientists examined the EEG signals and"
TEMPERATURE = 0.9
TOP_K = 80                 # will be clamped safely
MAX_NEW_TOKENS = 220

def top_k_logits(logits, k):
    if not k or k <= 0:
        return logits
    k = min(k, logits.size(-1))         # clamp to vocab size
    v, ix = torch.topk(logits, k, dim=-1)
    out = torch.full_like(logits, float("-inf"))
    out.scatter_(dim=-1, index=ix, src=v)
    return out

block_size = model.config.block_size
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)

ctx = torch.tensor([encode(PROMPT)], dtype=torch.long, device=device)
if ctx.size(1) == 0:
    ctx = torch.tensor([[stoi.get("\n", 0)]], dtype=torch.long, device=device)

generated = ctx.clone()
with torch.no_grad():
    for _ in range(MAX_NEW_TOKENS):
        idx_cond = generated[:, -block_size:]
        logits, _ = model(idx_cond)
        logits = logits[:, -1, :] / max(TEMPERATURE, 1e-6)
        logits = top_k_logits(logits, TOP_K)
        probs = torch.softmax(logits, dim=-1)
        next_id = torch.multinomial(probs, num_samples=1)
        generated = torch.cat([generated, next_id], dim=1)

text = decode(generated[0].tolist())
stamp = time.strftime("%Y%m%d-%H%M%S")
out_file = out_dir / f"sample_direct_T{TEMPERATURE}_K{TOP_K}_{stamp}.txt"
out_file.write_text(text, encoding="utf-8")
print("✅ Wrote sample →", out_file)
print("\n--- Preview ---\n")
print(text[:1000], "...\n")
# Out:
# number of parameters: 12.62M
# ✅ Wrote sample → /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/out_onegroup/sample_direct_T0.9_K80_20251028-182826.txt
#
# --- Preview ---
#
# In a quiet lab, the scientists examined the EEG signals and of
# That before the the prishers of my greets heart,
# To heart the patchair to our writher.
#
# DUKE OF YORK:
# Let your never pitience leave,
# Or the consulty.
#
# KING RICHARD II:
# I what, an it of my thing rerators,
# I sell wear  ...

# %%
# === Cell 9: qualitative rubric & quick checklist ===
from pathlib import Path

rubric_text = """Qualitative Evaluation (score 1–5; add short notes)

1) Generated text quality & coherence: _____
   Note:
2) Long-range dependencies (≈100+ token consistency): _____
   Note:
3) Grammatical correctness: _____
   Note:
4) Style consistency with training data: _____
   Note:

Additional observations:
- Repetitions / loops:
- Contradictions:
- Topic drift:
- Strengths:
- Failure cases:
"""

rubric_path = Path(OUT_DIR) / "QUAL_RUBRIC.txt"
rubric_path.write_text(rubric_text, encoding="utf-8")
print("Rubric written →", rubric_path)

# Optional: preview the most recent generated sample
candidates = sorted(Path(OUT_DIR).glob("sample_direct_*.txt")) or sorted(Path(OUT_DIR).glob("sample_*.txt"))
if candidates:
    latest = candidates[-1]
    print("\n--- Latest sample preview:", latest.name, "---\n")
    print(latest.read_text(encoding="utf-8")[:1200], "...\n")
else:
    print("No sample file found yet. Run your sampling cell first (Cell 8).")
# Out:
# Rubric written → /home/STUDENTS/mc1836/projects/torch/Group 3/nanoGPT/out_onegroup/QUAL_RUBRIC.txt
#
# --- Latest sample preview: sample_direct_T0.9_K80_20251028-182826.txt ---
#
# In a quiet lab, the scientists examined the EEG signals and of
# That before the the prishers of my greets heart,
# To heart the patchair to our writher.
#
# DUKE OF YORK:
# Let your never pitience leave,
# Or the consulty.
#
# KING RICHARD II:
# I what, an it of my thing rerators,
# I sell wear  ...
