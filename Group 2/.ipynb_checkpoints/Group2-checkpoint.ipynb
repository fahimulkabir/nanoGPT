# %%
# === Cell 1: clone NanoGPT & set paths ===
import os, json, sys
from pathlib import Path

# clone (skip if already cloned)
if not Path("nanoGPT").exists():
    # !git clone https://github.com/karpathy/nanoGPT.git

REPO_DIR = str(Path("nanoGPT").resolve())
OUT_DIR  = str(Path(REPO_DIR) / "out_onegroup")   # keep our runs separate
DATA_DIR = str(Path(REPO_DIR) / "data" / "shakespeare_char")  # we'll use Tiny Shakespeare

TRAIN_PY  = str(Path(REPO_DIR) / "train.py")
MODEL_PY  = str(Path(REPO_DIR) / "model.py")
SAMPLE_PY = str(Path(REPO_DIR) / "sample.py")

os.makedirs(OUT_DIR, exist_ok=True)

print("REPO_DIR:", REPO_DIR)
print("OUT_DIR :", OUT_DIR)
print("Files exist:", {
    "train.py": os.path.exists(TRAIN_PY),
    "model.py": os.path.exists(MODEL_PY),
    "sample.py": os.path.exists(SAMPLE_PY),
})
# Out:
# Cloning into 'nanoGPT'...
# remote: Enumerating objects: 686, done.
# remote: Total 686 (delta 0), reused 0 (delta 0), pack-reused 686 (from 1)
# Receiving objects: 100% (686/686), 974.06 KiB | 5.57 MiB/s, done.
# Resolving deltas: 100% (380/380), done.
# REPO_DIR: /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT
# OUT_DIR : /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/out_onegroup
# Files exist: {'train.py': True, 'model.py': True, 'sample.py': True}

# %%
# !python nanoGPT/data/shakespeare_char/prepare.py
# Out:
# length of dataset in characters: 1,115,394
# all the unique characters:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# vocab size: 65
# train has 1,003,854 tokens
# val has 111,540 tokens

# %%
# === Cell 2: prepare Tiny Shakespeare data ===
import os
from pathlib import Path

# run the repo's prepare script
# %cd "$REPO_DIR"
# !python data/shakespeare_char/prepare.py
# %cd - > /dev/null

# confirm files
data_files = list(Path(DATA_DIR).glob("*"))
print("DATA_DIR:", DATA_DIR)
for p in data_files:
    print(" -", p.name)
# Out:
# /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT
# length of dataset in characters: 1,115,394
# all the unique characters:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# vocab size: 65
# train has 1,003,854 tokens
# val has 111,540 tokens
# [Errno 2] No such file or directory: '- > /dev/null'
# /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT
# DATA_DIR: /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/data/shakespeare_char
#  - input.txt
#  - val.bin
#  - meta.pkl
#  - readme.md
#  - train.bin
#  - prepare.py

# %%
# === Cell 3: write single-group config_override.json ===
import json, os
from pathlib import Path

# A reasonable "one group" student config (small & quick)
cfg = {
    # architecture
    "block_size": 128,
    "n_layer": 6,
    "n_head": 4,
    "n_embd": 384,
    "dropout": 0.1,
    # training
    "batch_size": 16,
    "max_iters": 500,
    "learning_rate": 3e-4,
    "weight_decay": 1e-1,
    "beta1": 0.9,
    "beta2": 0.95,
    "grad_clip": 1.0,
    "decay_lr": True,
    "warmup_iters": 50,
    "lr_decay_iters": 500,
    "min_lr": 1e-5,
    # eval/checkpoint cadence
    "eval_interval": 50,
    "eval_iters": 100,
    "always_save_checkpoint": True,
    "eval_only": False,
    # I/O
    "out_dir": str(Path(REPO_DIR) / "out_group2"),
    "data_dir": DATA_DIR,
    # speed / debug
    "compile": False
}

ovr_path = str(Path(OUT_DIR) / "config_override.json")
with open(ovr_path, "w") as f:
    json.dump(cfg, f, indent=2)

print("Wrote override ->", ovr_path)
print(json.dumps(cfg, indent=2))
# Out:
# Wrote override -> /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/out_onegroup/config_override.json
# {
#   "block_size": 128,
#   "n_layer": 6,
#   "n_head": 4,
#   "n_embd": 384,
#   "dropout": 0.1,
#   "batch_size": 16,
#   "max_iters": 500,
#   "learning_rate": 0.0003,
#   "weight_decay": 0.1,
#   "beta1": 0.9,
#   "beta2": 0.95,
#   "grad_clip": 1.0,
#   "decay_lr": true,
#   "warmup_iters": 50,
#   "lr_decay_iters": 500,
#   "min_lr": 1e-05,
#   "eval_interval": 50,
#   "eval_iters": 100,
#   "always_save_checkpoint": true,
#   "eval_only": false,
#   "out_dir": "/home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/out_group2",
#   "data_dir": "/home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/data/shakespeare_char",
#   "compile": false
# }

# %%
# === Cell 4: patch train.py (idempotent) ===
from pathlib import Path
import re

tp = Path(TRAIN_PY).read_text()

# 1) Ensure it loads our override JSON early (affects out_dir, data_dir, etc.)
if "BEGIN: config override loader (onegroup)" not in tp:
    insert_after = tp.find("# -----------------------------------------------------------------------------\nconfig_keys")
    if insert_after == -1:
        insert_after = 0
    loader = f"""
# ==== BEGIN: config override loader (onegroup) ====
import json as _json
try:
    _OVR = r"{ovr_path}"
    if os.path.exists(_OVR):
        with open(_OVR, "r") as _f:
            _ovr = _json.load(_f)
        def _set(name, default=None):
            globals()[name] = _ovr.get(name, globals().get(name, default))
        # core
        _set("block_size")
        _set("n_layer"); _set("n_head"); _set("n_embd")
        _set("dropout")
        _set("batch_size"); _set("max_iters")
        # opt
        _set("learning_rate"); _set("weight_decay")
        _set("beta1"); _set("beta2")
        _set("grad_clip")
        _set("decay_lr"); _set("warmup_iters"); _set("lr_decay_iters"); _set("min_lr")
        # io
        _set("out_dir"); _set("eval_interval"); _set("eval_iters")
        _set("always_save_checkpoint"); _set("eval_only")
        _set("compile")
        # dataset resolution
        globals()["data_dir"] = _ovr.get("data_dir", os.path.join('data', globals().get("dataset","openwebtext")))
        print(f"[train.py] Loaded override from {{_OVR}}")
except Exception as _e:
    print("[train.py] Override load failed:", _e)
# ==== END: config override loader (onegroup) ====
"""
    tp = tp.replace("config = {k: globals()[k] for k in config_keys} # will be useful for logging",
                    "config = {k: globals()[k] for k in config_keys} # will be useful for logging\n" + loader)

# 2) Loss logger defined BEFORE training loop
if "BEGIN: loss logger (onegroup)" not in tp:
    loss_logger = """
# ==== BEGIN: loss logger (onegroup) ====
import csv as _csv
try:
    os.makedirs(out_dir, exist_ok=True)
except Exception:
    out_dir = "out"
    os.makedirs(out_dir, exist_ok=True)
_loss_csv = os.path.join(out_dir, "loss_log.csv")
if not os.path.exists(_loss_csv):
    with open(_loss_csv, "w", newline="") as _f:
        _w = _csv.writer(_f); _w.writerow(["iter","split","loss"])
def _append_loss_row(it, split, loss):
    try:
        with open(_loss_csv, "a", newline="") as _f:
            _w = _csv.writer(_f); _w.writerow([int(it), str(split), float(loss)])
    except Exception as _e:
        print("[warn] could not write loss log:", _e)
# ==== END: loss logger (onegroup) ====
"""
    # put it after the get_lr function (safe place)
    anchor = "def get_lr(it):"
    idx = tp.find(anchor)
    if idx != -1:
        end = tp.find("\n", idx)
        tp = tp[:end] + "\n" + loss_logger + tp[end:]
    else:
        tp = tp + "\n" + loss_logger

# 3) Log eval losses inside estimate_loss() before return
if "eval loss log (onegroup)" not in tp:
    tp = re.sub(
        r"(def\s+estimate_loss\s*\(\)\s*:\s*\n(?:.|\n)*?return\s+out)",
        r"""def estimate_loss():
    out = {}
    model.eval()
    for split in ['train','val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            with ctx:
                logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    # === eval loss log (onegroup) ===
    try:
        for _s, _v in out.items():
            _append_loss_row(iter_num, _s, float(_v))
    except Exception as _e:
        print("[warn] eval loss log failed:", _e)
    return out""",
        tp, count=1, flags=re.DOTALL
    )

# 4) Log train loss once per iteration where it prints the iter line
if "train loss log (onegroup)" not in tp:
    tp = tp.replace(
        "print(f\"iter {iter_num}: loss {lossf:.4f}, time {dt*1000:.2f}ms, mfu {running_mfu*100:.2f}%\")",
        "print(f\"iter {iter_num}: loss {lossf:.4f}, time {dt*1000:.2f}ms, mfu {running_mfu*100:.2f}%\")\n"
        "        try:\n"
        "            _append_loss_row(iter_num, 'train', float(lossf))\n"
        "        except Exception as _e:\n"
        "            print('[warn] train loss log failed:', _e)"
    )

# 5) Switch to new GradScaler API (silence deprecation)
tp = tp.replace("torch.cuda.amp.GradScaler(", "torch.amp.GradScaler('cuda', ")

Path(TRAIN_PY).write_text(tp)
print("train.py patched ✅")
# Out:
# train.py patched ✅

# %%
# === FIX train.py indentation + logger placement ===
from pathlib import Path
import re, textwrap

tp_path = Path(REPO_DIR) / "train.py"
txt = tp_path.read_text()

# 1. remove any previously inserted logger blocks that caused the indent error
txt = re.sub(r"# ==== BEGIN: loss logger.*?# ==== END: loss logger.*?====", "", txt, flags=re.S)

# 2. inject clean logger block near top (right after imports)
logger_block = textwrap.dedent("""
# ==== BEGIN: loss logger (onegroup fixed) ====
import csv as _csv, os
_loss_csv = os.path.join(out_dir, "loss_log.csv")
os.makedirs(out_dir, exist_ok=True)
if not os.path.exists(_loss_csv):
    with open(_loss_csv, "w", newline="") as _f:
        _csv.writer(_f).writerow(["iter","split","loss"])

def _append_loss_row(it, split, loss):
    try:
        with open(_loss_csv, "a", newline="") as _f:
            _csv.writer(_f).writerow([int(it), str(split), float(loss)])
    except Exception as _e:
        print("[warn] could not write loss log:", _e)
# ==== END: loss logger (onegroup fixed) ====
""")

# place it right after first import block
insert_at = txt.find("from model import GPTConfig, GPT")
if insert_at != -1:
    end = txt.find("\n", insert_at) + 1
    txt = txt[:end] + logger_block + txt[end:]
else:
    txt = logger_block + "\n" + txt

tp_path.write_text(txt)
print("✅ train.py fixed: logger inserted at top-level (no indentation error).")
# Out:
# ✅ train.py fixed: logger inserted at top-level (no indentation error).

# %%
# !head -n 300 "$REPO_DIR/train.py" | grep "loss logger"
# Out:
# # ==== BEGIN: loss logger (onegroup fixed) ====
# # ==== END: loss logger (onegroup fixed) ====

# %%
# === FIX: move logger below out_dir definition ===
from pathlib import Path
import re, textwrap

tp_path = Path(REPO_DIR) / "train.py"
txt = tp_path.read_text()

# Remove any prior inserted logger blocks
txt = re.sub(r"# ==== BEGIN: loss logger.*?# ==== END: loss logger.*?====", "", txt, flags=re.S)

# Build clean logger block (depends on out_dir)
logger_block = textwrap.dedent("""
# ==== BEGIN: loss logger (onegroup fixed, after out_dir) ====
import csv as _csv, os
_loss_csv = os.path.join(out_dir, "loss_log.csv")
os.makedirs(out_dir, exist_ok=True)
if not os.path.exists(_loss_csv):
    with open(_loss_csv, "w", newline="") as _f:
        _csv.writer(_f).writerow(["iter","split","loss"])

def _append_loss_row(it, split, loss):
    try:
        with open(_loss_csv, "a", newline="") as _f:
            _csv.writer(_f).writerow([int(it), str(split), float(loss)])
    except Exception as _e:
        print("[warn] could not write loss log:", _e)
# ==== END: loss logger (onegroup fixed, after out_dir) ====
""")

# Find insertion point: right after the first occurrence of "out_dir ="
idx = txt.find("out_dir =")
if idx == -1:
    raise RuntimeError("Could not find 'out_dir =' in train.py; please verify file.")
line_end = txt.find("\n", idx)
patched = txt[:line_end+1] + logger_block + txt[line_end+1:]

tp_path.write_text(patched)
print("✅ Logger moved below out_dir definition. Ready to train again.")
# Out:
# ✅ Logger moved below out_dir definition. Ready to train again.

# %%
# --- Patch train.py: stop overwriting data_dir to 'data/openwebtext' ---
from pathlib import Path
import re

tp_path = Path(REPO_DIR) / "train.py"
txt = tp_path.read_text()

# Replace the hard assignment:
#   data_dir = os.path.join('data', dataset)
# with a guarded version that respects an override:
patched = re.sub(
    r"\bdata_dir\s*=\s*os\.path\.join\('data',\s*dataset\)",
    "data_dir = globals().get('data_dir') or os.path.join('data', dataset)",
    txt,
    count=1
)

tp_path.write_text(patched)
print("Patched train.py to respect overridden data_dir.")
# Out:
# Patched train.py to respect overridden data_dir.

# %%
# === Cell 5 (fixed) ===
import os
from pathlib import Path

os.chdir(REPO_DIR)
# !python train.py
os.chdir("..")
# Out:
# [train.py] Loaded override from /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/out_onegroup/config_override.json
# tokens per iteration will be: 81,920
# /home/STUDENTS/mc1836/miniconda3/envs/torch/lib/python3.11/site-packages/torch/backends/__init__.py:46: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   self.setter(val)
# found vocab_size = 65 (inside /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/data/shakespeare_char/meta.pkl)
# Initializing a new model from scratch
# number of parameters: 10.65M
# num decayed parameter tensors: 26, with 10,690,944 parameters
# num non-decayed parameter tensors: 13, with 4,992 parameters
# using fused AdamW: True
# step 0: train loss 4.2505, val loss 4.2437
# iter 0: loss 4.2453, time 1984.48ms, mfu -100.00%
# iter 1: loss 4.1386, time 499.38ms, mfu -100.00%
# iter 2: loss 3.9498, time 506.00ms, mfu -100.00%
# iter 3: loss 3.6955, time 267.40ms, mfu -100.00%
# iter 4: loss 3.6124, time 267.45ms, mfu -100.00%
# iter 5: loss 3.4753, time 281.94ms, mfu 6.28%
# iter 6: loss 3.3718, time 733.36ms, mfu 5.89%
# iter 7: loss 3.3377, time 360.16ms, mfu 5.79%
# iter 8: loss 3.3209, time 315.21ms, mfu 5.78%
# iter 9: loss 3.2489, time 292.70ms, mfu 5.80%
# iter 10: loss 3.1517, time 640.79ms, mfu 5.50%
# iter 11: loss 3.1776, time 560.85ms, mfu 5.27%
# iter 12: loss 3.0932, time 292.42ms, mfu 5.34%
# iter 13: loss 3.1092, time 308.09ms, mfu 5.38%
# iter 14: loss 2.9496, time 399.50ms, mfu 5.29%
# iter 15: loss 2.9735, time 592.22ms, mfu 5.06%
# iter 16: loss 2.8800, time 358.99ms, mfu 5.05%
# iter 17: loss 2.8765, time 308.20ms, mfu 5.12%
# iter 18: loss 2.8073, time 287.40ms, mfu 5.22%
# iter 19: loss 2.8077, time 619.71ms, mfu 4.98%
# iter 20: loss 2.7995, time 648.43ms, mfu 4.76%
# iter 21: loss 2.7208, time 393.92ms, mfu 4.73%
# iter 22: loss 2.7207, time 516.69ms, mfu 4.60%
# iter 23: loss 2.6988, time 273.06ms, mfu 4.79%
# iter 24: loss 2.7275, time 286.12ms, mfu 4.93%
# iter 25: loss 2.6926, time 335.93ms, mfu 4.96%
# iter 26: loss 2.6425, time 469.96ms, mfu 4.84%
# iter 27: loss 2.6303, time 560.18ms, mfu 4.68%
# iter 28: loss 2.6486, time 319.80ms, mfu 4.76%
# iter 29: loss 2.6095, time 299.10ms, mfu 4.88%
# iter 30: loss 2.6369, time 539.49ms, mfu 4.72%
# iter 31: loss 2.6052, time 694.73ms, mfu 4.50%
# iter 32: loss 2.5701, time 601.60ms, mfu 4.34%
# iter 33: loss 2.5359, time 314.51ms, mfu 4.47%
# iter 34: loss 2.5450, time 394.60ms, mfu 4.47%
# iter 35: loss 2.5300, time 307.28ms, mfu 4.60%
# iter 36: loss 2.5800, time 306.19ms, mfu 4.72%
# iter 37: loss 2.5557, time 301.88ms, mfu 4.84%
# iter 38: loss 2.5811, time 673.15ms, mfu 4.61%
# iter 39: loss 2.5752, time 580.20ms, mfu 4.46%
# iter 40: loss 2.5510, time 255.18ms, mfu 4.71%
# iter 41: loss 2.5393, time 251.19ms, mfu 4.94%
# iter 42: loss 2.5218, time 349.60ms, mfu 4.95%
# iter 43: loss 2.5457, time 331.35ms, mfu 4.99%
# iter 44: loss 2.5439, time 237.51ms, mfu 5.24%
# iter 45: loss 2.5049, time 568.09ms, mfu 5.03%
# iter 46: loss 2.5291, time 564.32ms, mfu 4.84%
# iter 47: loss 2.4936, time 271.86ms, mfu 5.00%
# iter 48: loss 2.4660, time 273.62ms, mfu 5.15%
# iter 49: loss 2.4477, time 239.98ms, mfu 5.37%
# step 50: train loss 2.4747, val loss 2.4808
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/out_group2
# iter 50: loss 2.4678, time 990.53ms, mfu 5.01%
# iter 51: loss 2.4545, time 545.40ms, mfu 4.84%
# iter 52: loss 2.5202, time 416.02ms, mfu 4.78%
# iter 53: loss 2.4986, time 245.17ms, mfu 5.02%
# iter 54: loss 2.5085, time 235.41ms, mfu 5.27%
# iter 55: loss 2.4745, time 202.63ms, mfu 5.62%
# iter 56: loss 2.4525, time 432.60ms, mfu 5.47%
# iter 57: loss 2.4715, time 546.38ms, mfu 5.24%
# iter 58: loss 2.4408, time 283.19ms, mfu 5.34%
# iter 59: loss 2.4559, time 278.65ms, mfu 5.45%
# iter 60: loss 2.4898, time 237.49ms, mfu 5.65%
# iter 61: loss 2.4817, time 231.93ms, mfu 5.84%
# iter 62: loss 2.4202, time 405.97ms, mfu 5.70%
# iter 63: loss 2.4597, time 318.77ms, mfu 5.68%
# iter 64: loss 2.4669, time 300.74ms, mfu 5.70%
# iter 65: loss 2.4494, time 531.06ms, mfu 5.47%
# iter 66: loss 2.4019, time 223.53ms, mfu 5.71%
# iter 67: loss 2.4511, time 256.34ms, mfu 5.83%
# iter 68: loss 2.4154, time 244.04ms, mfu 5.97%
# iter 69: loss 2.4143, time 232.63ms, mfu 6.14%
# iter 70: loss 2.4263, time 643.90ms, mfu 5.80%
# iter 71: loss 2.4622, time 327.18ms, mfu 5.76%
# iter 72: loss 2.4273, time 290.34ms, mfu 5.79%
# iter 73: loss 2.3640, time 385.31ms, mfu 5.67%
# iter 74: loss 2.4586, time 266.72ms, mfu 5.77%
# iter 75: loss 2.3736, time 260.74ms, mfu 5.87%
# iter 76: loss 2.3887, time 250.17ms, mfu 5.99%
# iter 77: loss 2.4206, time 296.90ms, mfu 5.99%
# iter 78: loss 2.3991, time 572.39ms, mfu 5.70%
# iter 79: loss 2.4242, time 245.84ms, mfu 5.85%
# iter 80: loss 2.3699, time 276.72ms, mfu 5.90%
# iter 81: loss 2.4073, time 228.95ms, mfu 6.09%
# iter 82: loss 2.3842, time 212.74ms, mfu 6.31%
# iter 83: loss 2.3858, time 205.72ms, mfu 6.54%
# iter 84: loss 2.3721, time 210.02ms, mfu 6.73%
# iter 85: loss 2.3634, time 357.11ms, mfu 6.55%
# iter 86: loss 2.3347, time 702.86ms, mfu 6.15%
# iter 87: loss 2.3739, time 281.86ms, mfu 6.16%
# iter 88: loss 2.3610, time 235.27ms, mfu 6.30%
# iter 89: loss 2.3757, time 204.35ms, mfu 6.53%
# iter 90: loss 2.3742, time 204.33ms, mfu 6.75%
# iter 91: loss 2.3965, time 200.79ms, mfu 6.95%
# iter 92: loss 2.3908, time 189.80ms, mfu 7.19%
# iter 93: loss 2.3975, time 196.04ms, mfu 7.38%
# iter 94: loss 2.3200, time 179.00ms, mfu 7.63%
# iter 95: loss 2.3254, time 180.01ms, mfu 7.85%
# iter 96: loss 2.3484, time 182.62ms, mfu 8.03%
# iter 97: loss 2.3541, time 182.05ms, mfu 8.20%
# iter 98: loss 2.3251, time 207.91ms, mfu 8.23%
# iter 99: loss 2.3375, time 191.48ms, mfu 8.33%
# step 100: train loss 2.2909, val loss 2.3028
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/out_group2
# iter 100: loss 2.3309, time 671.90ms, mfu 7.76%
# iter 101: loss 2.3895, time 181.09ms, mfu 7.96%
# iter 102: loss 2.3514, time 189.78ms, mfu 8.10%
# iter 103: loss 2.3653, time 192.00ms, mfu 8.21%
# iter 104: loss 2.2855, time 183.40ms, mfu 8.36%
# iter 105: loss 2.2504, time 189.18ms, mfu 8.46%
# iter 106: loss 2.3603, time 187.98ms, mfu 8.55%
# iter 107: loss 2.2881, time 194.26ms, mfu 8.61%
# iter 108: loss 2.2885, time 187.53ms, mfu 8.69%
# iter 109: loss 2.3207, time 195.02ms, mfu 8.73%
# iter 110: loss 2.3217, time 260.48ms, mfu 8.54%
# iter 111: loss 2.3418, time 218.50ms, mfu 8.49%
# iter 112: loss 2.2958, time 260.93ms, mfu 8.32%
# iter 113: loss 2.2990, time 194.34ms, mfu 8.40%
# iter 114: loss 2.2437, time 202.05ms, mfu 8.44%
# iter 115: loss 2.2941, time 253.52ms, mfu 8.29%
# iter 116: loss 2.2590, time 204.88ms, mfu 8.33%
# iter 117: loss 2.2567, time 193.45ms, mfu 8.41%
# iter 118: loss 2.3232, time 186.95ms, mfu 8.51%
# iter 119: loss 2.2630, time 190.21ms, mfu 8.59%
# iter 120: loss 2.2367, time 187.04ms, mfu 8.68%
# iter 121: loss 2.2025, time 189.85ms, mfu 8.75%
# iter 122: loss 2.2621, time 181.03ms, mfu 8.85%
# iter 123: loss 2.2605, time 181.11ms, mfu 8.94%
# iter 124: loss 2.2817, time 180.99ms, mfu 9.03%
# iter 125: loss 2.2221, time 175.91ms, mfu 9.13%
# iter 126: loss 2.1820, time 188.04ms, mfu 9.16%
# iter 127: loss 2.2252, time 186.85ms, mfu 9.19%
# iter 128: loss 2.1979, time 218.22ms, mfu 9.08%
# iter 129: loss 2.1907, time 277.33ms, mfu 8.81%
# iter 130: loss 2.2168, time 257.64ms, mfu 8.62%
# iter 131: loss 2.2567, time 268.70ms, mfu 8.41%
# iter 132: loss 2.2464, time 271.76ms, mfu 8.22%
# iter 133: loss 2.2133, time 274.23ms, mfu 8.05%
# iter 134: loss 2.2078, time 271.64ms, mfu 7.89%
# iter 135: loss 2.1966, time 274.57ms, mfu 7.75%
# iter 136: loss 2.2045, time 271.51ms, mfu 7.63%
# iter 137: loss 2.2106, time 275.25ms, mfu 7.51%
# iter 138: loss 2.2318, time 269.14ms, mfu 7.41%
# iter 139: loss 2.1491, time 274.11ms, mfu 7.32%
# iter 140: loss 2.1743, time 252.14ms, mfu 7.29%
# iter 141: loss 2.1755, time 264.78ms, mfu 7.23%
# iter 142: loss 2.1179, time 266.69ms, mfu 7.17%
# iter 143: loss 2.2582, time 255.11ms, mfu 7.15%
# iter 144: loss 2.1766, time 262.26ms, mfu 7.11%
# iter 145: loss 2.1717, time 264.05ms, mfu 7.07%
# iter 146: loss 2.1601, time 271.63ms, mfu 7.01%
# iter 147: loss 2.1472, time 273.47ms, mfu 6.96%
# iter 148: loss 2.1271, time 262.49ms, mfu 6.94%
# iter 149: loss 2.1385, time 264.94ms, mfu 6.91%
# step 150: train loss 2.0892, val loss 2.1343
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/out_group2
# iter 150: loss 2.1145, time 914.16ms, mfu 6.41%
# iter 151: loss 2.1668, time 251.85ms, mfu 6.47%
# iter 152: loss 2.1658, time 266.05ms, mfu 6.49%
# iter 153: loss 2.1216, time 261.45ms, mfu 6.52%
# iter 154: loss 2.0541, time 201.54ms, mfu 6.75%
# iter 155: loss 2.1394, time 186.06ms, mfu 7.02%
# iter 156: loss 2.1029, time 216.58ms, mfu 7.14%
# iter 157: loss 2.1281, time 277.52ms, mfu 7.06%
# iter 158: loss 2.1296, time 268.77ms, mfu 7.01%
# iter 159: loss 2.1021, time 269.39ms, mfu 6.97%
# iter 160: loss 2.1460, time 283.08ms, mfu 6.90%
# iter 161: loss 2.0402, time 253.93ms, mfu 6.91%
# iter 162: loss 2.0433, time 273.82ms, mfu 6.86%
# iter 163: loss 2.1483, time 263.05ms, mfu 6.85%
# iter 164: loss 2.1072, time 273.60ms, mfu 6.81%
# iter 165: loss 2.0888, time 266.86ms, mfu 6.79%
# iter 166: loss 2.0669, time 272.01ms, mfu 6.76%
# iter 167: loss 2.1177, time 248.20ms, mfu 6.80%
# iter 168: loss 2.0772, time 265.11ms, mfu 6.79%
# iter 169: loss 2.0874, time 270.32ms, mfu 6.76%
# iter 170: loss 2.0665, time 277.99ms, mfu 6.73%
# iter 171: loss 1.9846, time 280.23ms, mfu 6.68%
# iter 172: loss 2.0234, time 261.91ms, mfu 6.69%
# iter 173: loss 2.0241, time 267.87ms, mfu 6.68%
# iter 174: loss 2.0073, time 272.54ms, mfu 6.66%
# iter 175: loss 2.0588, time 250.41ms, mfu 6.71%
# iter 176: loss 2.1327, time 257.99ms, mfu 6.72%
# iter 177: loss 2.0293, time 271.27ms, mfu 6.70%
# iter 178: loss 1.9971, time 270.40ms, mfu 6.69%
# iter 179: loss 2.0351, time 257.54ms, mfu 6.70%
# iter 180: loss 1.9957, time 270.91ms, mfu 6.69%
# iter 181: loss 1.9486, time 279.54ms, mfu 6.65%
# iter 182: loss 2.0450, time 277.37ms, mfu 6.63%
# iter 183: loss 2.0370, time 280.08ms, mfu 6.59%
# iter 184: loss 2.0440, time 204.81ms, mfu 6.80%
# iter 185: loss 2.0269, time 183.75ms, mfu 7.08%
# iter 186: loss 1.9755, time 185.17ms, mfu 7.33%
# iter 187: loss 2.0591, time 210.30ms, mfu 7.44%
# iter 188: loss 1.9782, time 273.71ms, mfu 7.34%
# iter 189: loss 2.0203, time 278.08ms, mfu 7.24%
# iter 190: loss 1.9425, time 269.88ms, mfu 7.18%
# iter 191: loss 2.0168, time 273.94ms, mfu 7.10%
# iter 192: loss 1.9939, time 280.15ms, mfu 7.03%
# iter 193: loss 2.0081, time 278.04ms, mfu 6.96%
# iter 194: loss 1.9700, time 281.53ms, mfu 6.89%
# iter 195: loss 1.9741, time 278.28ms, mfu 6.84%
# iter 196: loss 2.0082, time 275.46ms, mfu 6.80%
# iter 197: loss 1.9686, time 276.51ms, mfu 6.76%
# iter 198: loss 1.9720, time 277.18ms, mfu 6.72%
# iter 199: loss 1.9689, time 281.54ms, mfu 6.68%
# step 200: train loss 1.8818, val loss 1.9799
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/out_group2
# iter 200: loss 1.9055, time 972.23ms, mfu 6.19%
# iter 201: loss 1.9071, time 273.16ms, mfu 6.22%
# iter 202: loss 1.9213, time 277.11ms, mfu 6.24%
# iter 203: loss 1.9616, time 272.83ms, mfu 6.26%
# iter 204: loss 1.9311, time 274.06ms, mfu 6.28%
# iter 205: loss 1.9328, time 272.03ms, mfu 6.30%
# iter 206: loss 1.9744, time 274.43ms, mfu 6.32%
# iter 207: loss 1.8674, time 275.91ms, mfu 6.33%
# iter 208: loss 1.9861, time 274.81ms, mfu 6.34%
# iter 209: loss 1.9840, time 276.50ms, mfu 6.35%
# iter 210: loss 1.9452, time 273.89ms, mfu 6.36%
# iter 211: loss 1.9392, time 223.96ms, mfu 6.51%
# iter 212: loss 1.9674, time 181.04ms, mfu 6.84%
# iter 213: loss 1.9099, time 180.48ms, mfu 7.14%
# iter 214: loss 1.9113, time 187.48ms, mfu 7.37%
# iter 215: loss 1.8956, time 267.33ms, mfu 7.29%
# iter 216: loss 1.8573, time 281.63ms, mfu 7.19%
# iter 217: loss 1.8887, time 276.60ms, mfu 7.11%
# iter 218: loss 1.8914, time 267.62ms, mfu 7.06%
# iter 219: loss 1.9446, time 283.10ms, mfu 6.98%
# iter 220: loss 1.8295, time 271.47ms, mfu 6.94%
# iter 221: loss 1.8745, time 271.50ms, mfu 6.89%
# iter 222: loss 1.8182, time 278.63ms, mfu 6.84%
# iter 223: loss 1.8312, time 283.03ms, mfu 6.78%
# iter 224: loss 1.9889, time 273.50ms, mfu 6.75%
# iter 225: loss 1.8839, time 275.53ms, mfu 6.72%
# iter 226: loss 1.8605, time 274.92ms, mfu 6.69%
# iter 227: loss 1.8731, time 273.59ms, mfu 6.67%
# iter 228: loss 1.8047, time 280.68ms, mfu 6.63%
# iter 229: loss 1.8610, time 282.04ms, mfu 6.60%
# iter 230: loss 1.8893, time 283.29ms, mfu 6.56%
# iter 231: loss 1.8175, time 279.80ms, mfu 6.54%
# iter 232: loss 1.9035, time 279.21ms, mfu 6.52%
# iter 233: loss 1.8263, time 281.15ms, mfu 6.50%
# iter 234: loss 1.8297, time 275.22ms, mfu 6.49%
# iter 235: loss 1.8803, time 282.22ms, mfu 6.47%
# iter 236: loss 1.8834, time 281.75ms, mfu 6.45%
# iter 237: loss 1.7949, time 275.92ms, mfu 6.45%
# iter 238: loss 1.8333, time 280.19ms, mfu 6.43%
# iter 239: loss 1.7459, time 279.68ms, mfu 6.42%
# iter 240: loss 1.8068, time 282.54ms, mfu 6.41%
# iter 241: loss 1.8568, time 228.23ms, mfu 6.54%
# iter 242: loss 1.8332, time 177.62ms, mfu 6.88%
# iter 243: loss 1.8209, time 185.61ms, mfu 7.15%
# iter 244: loss 1.7408, time 182.71ms, mfu 7.40%
# iter 245: loss 1.8108, time 253.70ms, mfu 7.36%
# iter 246: loss 1.8115, time 278.30ms, mfu 7.26%
# iter 247: loss 1.8249, time 280.84ms, mfu 7.17%
# iter 248: loss 1.7554, time 280.20ms, mfu 7.08%
# iter 249: loss 1.7943, time 262.42ms, mfu 7.05%
# step 250: train loss 1.7387, val loss 1.8730
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/out_group2
# iter 250: loss 1.7936, time 988.01ms, mfu 6.52%
# iter 251: loss 1.7976, time 271.79ms, mfu 6.52%
# iter 252: loss 1.8406, time 259.90ms, mfu 6.55%
# iter 253: loss 1.8324, time 256.32ms, mfu 6.59%
# iter 254: loss 1.8282, time 268.89ms, mfu 6.59%
# iter 255: loss 1.8056, time 279.45ms, mfu 6.56%
# iter 256: loss 1.7545, time 252.90ms, mfu 6.60%
# iter 257: loss 1.8187, time 269.74ms, mfu 6.60%
# iter 258: loss 1.7974, time 261.99ms, mfu 6.62%
# iter 259: loss 1.6880, time 435.62ms, mfu 6.36%
# iter 260: loss 1.7352, time 338.14ms, mfu 6.25%
# iter 261: loss 1.7810, time 227.02ms, mfu 6.40%
# iter 262: loss 1.7190, time 268.61ms, mfu 6.42%
# iter 263: loss 1.7465, time 242.62ms, mfu 6.51%
# iter 264: loss 1.7713, time 260.21ms, mfu 6.54%
# iter 265: loss 1.7329, time 262.81ms, mfu 6.56%
# iter 266: loss 1.7328, time 260.49ms, mfu 6.58%
# iter 267: loss 1.7637, time 253.19ms, mfu 6.62%
# iter 268: loss 1.7539, time 254.26ms, mfu 6.66%
# iter 269: loss 1.7947, time 243.49ms, mfu 6.72%
# iter 270: loss 1.7686, time 595.55ms, mfu 6.34%
# iter 271: loss 1.6968, time 738.68ms, mfu 5.95%
# iter 272: loss 1.8531, time 229.51ms, mfu 6.13%
# iter 273: loss 1.7128, time 229.57ms, mfu 6.28%
# iter 274: loss 1.7612, time 223.51ms, mfu 6.45%
# iter 275: loss 1.7889, time 227.44ms, mfu 6.58%
# iter 276: loss 1.7791, time 230.12ms, mfu 6.69%
# iter 277: loss 1.7513, time 241.40ms, mfu 6.76%
# iter 278: loss 1.7349, time 243.66ms, mfu 6.81%
# iter 279: loss 1.7405, time 242.67ms, mfu 6.86%
# iter 280: loss 1.7561, time 246.02ms, mfu 6.89%
# iter 281: loss 1.7763, time 250.22ms, mfu 6.91%
# iter 282: loss 1.7400, time 233.94ms, mfu 6.97%
# iter 283: loss 1.7936, time 243.47ms, mfu 7.00%
# iter 284: loss 1.7429, time 251.68ms, mfu 7.01%
# iter 285: loss 1.6250, time 235.64ms, mfu 7.06%
# iter 286: loss 1.8015, time 231.71ms, mfu 7.12%
# iter 287: loss 1.7574, time 263.10ms, mfu 7.08%
# iter 288: loss 1.7697, time 273.98ms, mfu 7.02%
# iter 289: loss 1.6531, time 262.17ms, mfu 6.99%
# iter 290: loss 1.7277, time 260.87ms, mfu 6.97%
# iter 291: loss 1.7234, time 280.29ms, mfu 6.90%
# iter 292: loss 1.7610, time 280.17ms, mfu 6.84%
# iter 293: loss 1.7253, time 319.61ms, mfu 6.71%
# iter 294: loss 1.6489, time 458.69ms, mfu 6.43%
# iter 295: loss 1.7530, time 504.56ms, mfu 6.14%
# iter 296: loss 1.6892, time 513.51ms, mfu 5.87%
# iter 297: loss 1.7366, time 362.28ms, mfu 5.77%
# iter 298: loss 1.6465, time 316.21ms, mfu 5.75%
# iter 299: loss 1.7106, time 289.68ms, mfu 5.79%
# step 300: train loss 1.6284, val loss 1.7886
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/out_group2
# iter 300: loss 1.5809, time 1713.44ms, mfu 5.31%
# iter 301: loss 1.7705, time 470.79ms, mfu 5.16%
# iter 302: loss 1.7128, time 361.22ms, mfu 5.13%
# iter 303: loss 1.7133, time 261.88ms, mfu 5.29%
# iter 304: loss 1.7027, time 625.36ms, mfu 5.05%
# iter 305: loss 1.6708, time 513.57ms, mfu 4.89%
# iter 306: loss 1.6943, time 339.63ms, mfu 4.92%
# iter 307: loss 1.6900, time 493.86ms, mfu 4.79%
# iter 308: loss 1.7081, time 331.36ms, mfu 4.84%
# iter 309: loss 1.7209, time 275.09ms, mfu 5.00%
# iter 310: loss 1.6875, time 289.68ms, mfu 5.11%
# iter 311: loss 1.6153, time 317.49ms, mfu 5.16%
# iter 312: loss 1.6570, time 295.55ms, mfu 5.24%
# iter 313: loss 1.6729, time 300.78ms, mfu 5.31%
# iter 314: loss 1.6721, time 574.21ms, mfu 5.08%
# iter 315: loss 1.6239, time 505.91ms, mfu 4.93%
# iter 316: loss 1.7184, time 373.23ms, mfu 4.91%
# iter 317: loss 1.7071, time 413.70ms, mfu 4.84%
# iter 318: loss 1.6660, time 515.67ms, mfu 4.70%
# iter 319: loss 1.7050, time 528.88ms, mfu 4.57%
# iter 320: loss 1.6538, time 557.73ms, mfu 4.43%
# iter 321: loss 1.6681, time 661.63ms, mfu 4.25%
# iter 322: loss 1.6689, time 412.79ms, mfu 4.26%
# iter 323: loss 1.6909, time 484.80ms, mfu 4.20%
# iter 324: loss 1.5866, time 498.13ms, mfu 4.13%
# iter 325: loss 1.6375, time 448.24ms, mfu 4.11%
# iter 326: loss 1.6435, time 435.66ms, mfu 4.11%
# iter 327: loss 1.7092, time 418.99ms, mfu 4.12%
# iter 328: loss 1.6355, time 636.38ms, mfu 3.99%
# iter 329: loss 1.6985, time 407.45ms, mfu 4.02%
# iter 330: loss 1.7528, time 418.60ms, mfu 4.04%
# iter 331: loss 1.6995, time 429.15ms, mfu 4.05%
# iter 332: loss 1.8015, time 623.11ms, mfu 3.93%
# iter 333: loss 1.6488, time 626.23ms, mfu 3.82%
# iter 334: loss 1.6555, time 476.67ms, mfu 3.81%
# iter 335: loss 1.6719, time 584.12ms, mfu 3.73%
# iter 336: loss 1.6903, time 501.73ms, mfu 3.71%
# iter 337: loss 1.6380, time 428.40ms, mfu 3.75%
# iter 338: loss 1.6136, time 433.38ms, mfu 3.79%
# iter 339: loss 1.7214, time 584.57ms, mfu 3.71%
# iter 340: loss 1.5937, time 556.82ms, mfu 3.66%
# iter 341: loss 1.7093, time 393.33ms, mfu 3.74%
# iter 342: loss 1.6559, time 424.47ms, mfu 3.78%
# iter 343: loss 1.6935, time 465.12ms, mfu 3.79%
# iter 344: loss 1.6624, time 493.39ms, mfu 3.77%
# iter 345: loss 1.6285, time 537.98ms, mfu 3.72%
# iter 346: loss 1.5386, time 317.55ms, mfu 3.90%
# iter 347: loss 1.6346, time 357.67ms, mfu 4.01%
# iter 348: loss 1.6848, time 407.77ms, mfu 4.04%
# iter 349: loss 1.5995, time 550.39ms, mfu 3.96%
# step 350: train loss 1.5650, val loss 1.7431
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/out_group2
# iter 350: loss 1.6651, time 2029.94ms, mfu 3.65%
# iter 351: loss 1.6432, time 430.86ms, mfu 3.70%
# iter 352: loss 1.6375, time 473.75ms, mfu 3.70%
# iter 353: loss 1.6150, time 597.45ms, mfu 3.63%
# iter 354: loss 1.5663, time 466.67ms, mfu 3.64%
# iter 355: loss 1.6137, time 449.73ms, mfu 3.67%
# iter 356: loss 1.6318, time 424.87ms, mfu 3.72%
# iter 357: loss 1.6506, time 456.38ms, mfu 3.74%
# iter 358: loss 1.5879, time 457.86ms, mfu 3.75%
# iter 359: loss 1.6597, time 433.13ms, mfu 3.78%
# iter 360: loss 1.6614, time 391.54ms, mfu 3.86%
# iter 361: loss 1.6347, time 406.67ms, mfu 3.91%
# iter 362: loss 1.5844, time 591.74ms, mfu 3.82%
# iter 363: loss 1.6496, time 644.50ms, mfu 3.71%
# iter 364: loss 1.6259, time 401.43ms, mfu 3.78%
# iter 365: loss 1.6149, time 471.41ms, mfu 3.78%
# iter 366: loss 1.5706, time 405.35ms, mfu 3.84%
# iter 367: loss 1.6193, time 605.62ms, mfu 3.74%
# iter 368: loss 1.6834, time 635.25ms, mfu 3.65%
# iter 369: loss 1.6123, time 661.01ms, mfu 3.55%
# iter 370: loss 1.6329, time 418.07ms, mfu 3.62%
# iter 371: loss 1.6308, time 421.24ms, mfu 3.68%
# iter 372: loss 1.6665, time 420.49ms, mfu 3.73%
# iter 373: loss 1.5882, time 419.79ms, mfu 3.78%
# iter 374: loss 1.6601, time 394.47ms, mfu 3.85%
# iter 375: loss 1.6448, time 432.81ms, mfu 3.87%
# iter 376: loss 1.6955, time 613.95ms, mfu 3.78%
# iter 377: loss 1.6888, time 389.69ms, mfu 3.85%
# iter 378: loss 1.5887, time 487.21ms, mfu 3.83%
# iter 379: loss 1.6881, time 583.06ms, mfu 3.75%
# iter 380: loss 1.6201, time 566.09ms, mfu 3.69%
# iter 381: loss 1.6369, time 466.41ms, mfu 3.70%
# iter 382: loss 1.6642, time 401.49ms, mfu 3.77%
# iter 383: loss 1.5655, time 464.73ms, mfu 3.77%
# iter 384: loss 1.5013, time 477.06ms, mfu 3.77%
# iter 385: loss 1.6234, time 608.42ms, mfu 3.68%
# iter 386: loss 1.6017, time 431.51ms, mfu 3.72%
# iter 387: loss 1.6580, time 425.10ms, mfu 3.77%
# iter 388: loss 1.6481, time 399.38ms, mfu 3.83%
# iter 389: loss 1.5186, time 425.02ms, mfu 3.87%
# iter 390: loss 1.6183, time 485.52ms, mfu 3.85%
# iter 391: loss 1.6324, time 628.42ms, mfu 3.74%
# iter 392: loss 1.6761, time 490.31ms, mfu 3.73%
# iter 393: loss 1.6280, time 488.90ms, mfu 3.72%
# iter 394: loss 1.6242, time 453.10ms, mfu 3.74%
# iter 395: loss 1.6437, time 510.74ms, mfu 3.71%
# iter 396: loss 1.6144, time 448.78ms, mfu 3.73%
# iter 397: loss 1.5709, time 462.34ms, mfu 3.74%
# iter 398: loss 1.6204, time 476.15ms, mfu 3.74%
# iter 399: loss 1.6537, time 413.14ms, mfu 3.79%
# step 400: train loss 1.5151, val loss 1.6960
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/out_group2
# iter 400: loss 1.6383, time 1945.42ms, mfu 3.51%
# iter 401: loss 1.5929, time 452.73ms, mfu 3.55%
# iter 402: loss 1.6413, time 421.77ms, mfu 3.61%
# iter 403: loss 1.5638, time 495.70ms, mfu 3.61%
# iter 404: loss 1.6460, time 658.29ms, mfu 3.52%
# iter 405: loss 1.5780, time 398.28ms, mfu 3.61%
# iter 406: loss 1.5843, time 419.13ms, mfu 3.67%
# iter 407: loss 1.6629, time 433.98ms, mfu 3.71%
# iter 408: loss 1.6250, time 504.42ms, mfu 3.69%
# iter 409: loss 1.5846, time 455.77ms, mfu 3.71%
# iter 410: loss 1.5761, time 510.38ms, mfu 3.69%
# iter 411: loss 1.5362, time 332.70ms, mfu 3.85%
# iter 412: loss 1.6581, time 309.76ms, mfu 4.04%
# iter 413: loss 1.6275, time 541.83ms, mfu 3.96%
# iter 414: loss 1.6280, time 588.90ms, mfu 3.86%
# iter 415: loss 1.6588, time 467.72ms, mfu 3.86%
# iter 416: loss 1.5195, time 415.96ms, mfu 3.90%
# iter 417: loss 1.5478, time 684.67ms, mfu 3.76%
# iter 418: loss 1.5742, time 571.56ms, mfu 3.70%
# iter 419: loss 1.6655, time 431.21ms, mfu 3.74%
# iter 420: loss 1.5578, time 410.97ms, mfu 3.80%
# iter 421: loss 1.5496, time 394.35ms, mfu 3.86%
# iter 422: loss 1.5446, time 466.18ms, mfu 3.86%
# iter 423: loss 1.5708, time 421.70ms, mfu 3.89%
# iter 424: loss 1.6009, time 415.89ms, mfu 3.93%
# iter 425: loss 1.5487, time 382.59ms, mfu 4.00%
# iter 426: loss 1.5750, time 623.61ms, mfu 3.88%
# iter 427: loss 1.5687, time 740.00ms, mfu 3.73%
# iter 428: loss 1.5475, time 390.61ms, mfu 3.81%
# iter 429: loss 1.5716, time 420.70ms, mfu 3.85%
# iter 430: loss 1.5890, time 595.58ms, mfu 3.76%
# iter 431: loss 1.5764, time 644.81ms, mfu 3.66%
# iter 432: loss 1.6583, time 579.10ms, mfu 3.60%
# iter 433: loss 1.6224, time 399.78ms, mfu 3.68%
# iter 434: loss 1.5385, time 428.97ms, mfu 3.73%
# iter 435: loss 1.5340, time 397.74ms, mfu 3.80%
# iter 436: loss 1.5255, time 404.52ms, mfu 3.86%
# iter 437: loss 1.6677, time 527.83ms, mfu 3.81%
# iter 438: loss 1.5309, time 389.14ms, mfu 3.88%
# iter 439: loss 1.6195, time 499.82ms, mfu 3.85%
# iter 440: loss 1.5788, time 472.62ms, mfu 3.84%
# iter 441: loss 1.5874, time 540.83ms, mfu 3.78%
# iter 442: loss 1.5918, time 538.58ms, mfu 3.73%
# iter 443: loss 1.5961, time 633.59ms, mfu 3.64%
# iter 444: loss 1.5502, time 519.87ms, mfu 3.61%
# iter 445: loss 1.5944, time 311.18ms, mfu 3.82%
# iter 446: loss 1.6773, time 285.35ms, mfu 4.06%
# iter 447: loss 1.5819, time 321.10ms, mfu 4.21%
# iter 448: loss 1.5993, time 305.42ms, mfu 4.36%
# iter 449: loss 1.6272, time 645.10ms, mfu 4.20%
# step 450: train loss 1.5043, val loss 1.6760
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/out_group2
# iter 450: loss 1.4787, time 1324.12ms, mfu 3.92%
# iter 451: loss 1.5801, time 384.05ms, mfu 3.99%
# iter 452: loss 1.5657, time 524.62ms, mfu 3.92%
# iter 453: loss 1.5558, time 459.39ms, mfu 3.92%
# iter 454: loss 1.6407, time 573.41ms, mfu 3.83%
# iter 455: loss 1.5103, time 532.28ms, mfu 3.78%
# iter 456: loss 1.5780, time 343.68ms, mfu 3.92%
# iter 457: loss 1.6216, time 448.93ms, mfu 3.92%
# iter 458: loss 1.5347, time 435.21ms, mfu 3.94%
# iter 459: loss 1.6106, time 309.46ms, mfu 4.12%
# iter 460: loss 1.5811, time 299.65ms, mfu 4.29%
# iter 461: loss 1.5504, time 345.51ms, mfu 4.38%
# iter 462: loss 1.4989, time 342.66ms, mfu 4.46%
# iter 463: loss 1.6224, time 340.70ms, mfu 4.53%
# iter 464: loss 1.6406, time 338.78ms, mfu 4.60%
# iter 465: loss 1.5811, time 284.46ms, mfu 4.76%
# iter 466: loss 1.5057, time 580.41ms, mfu 4.59%
# iter 467: loss 1.5469, time 451.12ms, mfu 4.52%
# iter 468: loss 1.5225, time 434.79ms, mfu 4.48%
# iter 469: loss 1.6059, time 631.57ms, mfu 4.31%
# iter 470: loss 1.5484, time 392.47ms, mfu 4.33%
# iter 471: loss 1.6479, time 694.08ms, mfu 4.15%
# iter 472: loss 1.6383, time 345.07ms, mfu 4.25%
# iter 473: loss 1.5496, time 268.91ms, mfu 4.48%
# iter 474: loss 1.5931, time 246.24ms, mfu 4.75%
# iter 475: loss 1.5145, time 274.10ms, mfu 4.92%
# iter 476: loss 1.5937, time 590.77ms, mfu 4.73%
# iter 477: loss 1.6196, time 326.37ms, mfu 4.80%
# iter 478: loss 1.5658, time 355.59ms, mfu 4.82%
# iter 479: loss 1.5543, time 355.19ms, mfu 4.84%
# iter 480: loss 1.5452, time 339.95ms, mfu 4.87%
# iter 481: loss 1.6062, time 452.08ms, mfu 4.78%
# iter 482: loss 1.5002, time 272.17ms, mfu 4.95%
# iter 483: loss 1.5731, time 274.23ms, mfu 5.10%
# iter 484: loss 1.5627, time 293.36ms, mfu 5.19%
# iter 485: loss 1.6242, time 482.60ms, mfu 5.04%
# iter 486: loss 1.6038, time 421.48ms, mfu 4.96%
# iter 487: loss 1.5552, time 408.97ms, mfu 4.89%
# iter 488: loss 1.6084, time 786.84ms, mfu 4.63%
# iter 489: loss 1.5828, time 726.75ms, mfu 4.41%
# iter 490: loss 1.5916, time 313.33ms, mfu 4.53%
# iter 491: loss 1.6744, time 286.44ms, mfu 4.70%
# iter 492: loss 1.5105, time 284.14ms, mfu 4.85%
# iter 493: loss 1.5290, time 277.93ms, mfu 5.00%
# iter 494: loss 1.4850, time 257.47ms, mfu 5.19%
# iter 495: loss 1.4854, time 706.15ms, mfu 4.92%
# iter 496: loss 1.5633, time 413.72ms, mfu 4.86%
# iter 497: loss 1.5194, time 306.11ms, mfu 4.95%
# iter 498: loss 1.5972, time 471.88ms, mfu 4.83%
# iter 499: loss 1.6024, time 313.86ms, mfu 4.91%
# step 500: train loss 1.4835, val loss 1.6708
# saving checkpoint to /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/out_group2
# iter 500: loss 1.5876, time 1147.38ms, mfu 4.57%

# %%
# === Cell 6: plot curves (train, val, gap) ===
import os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

log_csv = str(Path(OUT_DIR) / "loss_log.csv")
if not os.path.exists(log_csv):
    raise SystemExit("No loss_log.csv yet. Let training run (eval_interval small helps).")

df = pd.read_csv(log_csv)
if df.empty:
    raise SystemExit("loss_log.csv is empty.")

# --- Training curve ---
dft = df[df["split"] == "train"].sort_values("iter")
if not dft.empty:
    plt.figure()
    plt.plot(dft["iter"], dft["loss"])
    plt.title("Training Loss Curve")
    plt.xlabel("Iteration")
    plt.ylabel("Loss")
    plt.show()
else:
    print("No 'train' rows in loss_log.csv")

# --- Validation curve ---
dfv = df[df["split"] == "val"].sort_values("iter")
if not dfv.empty:
    plt.figure()
    plt.plot(dfv["iter"], dfv["loss"])
    plt.title("Validation Loss Curve")
    plt.xlabel("Iteration")
    plt.ylabel("Loss")
    plt.show()
else:
    print("No 'val' rows yet (run longer or lower eval_interval).")

# --- Train–Val Gap (nearest-neighbor align val to the latest <= train iter) ---
if not dft.empty and not dfv.empty:
    t_iters = dft["iter"].to_numpy()
    t_loss  = dft["loss"].to_numpy()

    aligned = []
    for _, r in dfv.iterrows():
        v_it, v_loss = int(r["iter"]), float(r["loss"])
        # index of latest train iter <= v_it; fallback to first train iter
        idx = np.searchsorted(t_iters, v_it, side="right") - 1
        if idx < 0:
            idx = 0
        aligned.append((v_it, v_loss - t_loss[idx]))

    adf = pd.DataFrame(aligned, columns=["iter", "gap"])
    plt.figure()
    plt.plot(adf["iter"], adf["gap"])
    plt.title("Train–Val Loss Gap (Overfitting Indicator)")
    plt.xlabel("Iteration (val)")
    plt.ylabel("Val - Train")
    plt.show()
else:
    print("Not enough data for gap curve yet (need both train and val).")

# %%
# === Cell 7: params & memory from last checkpoint ===
import os, importlib.util, torch
from pathlib import Path

CKPT = str(Path(OUT_DIR) / "ckpt.pt")
if not os.path.exists(CKPT):
    raise SystemExit("No checkpoint found. Let training run past the first eval (Cell 3 sets always_save_checkpoint=True).")

# import model module
spec = importlib.util.spec_from_file_location("nanogpt_model", MODEL_PY)
mod  = importlib.util.module_from_spec(spec)
spec.loader.exec_module(mod)

ckpt = torch.load(CKPT, map_location="cpu")
model_args = ckpt.get("model_args") or ckpt.get("config") or {}
gcfg = mod.GPTConfig(**model_args)
model = mod.GPT(gcfg)
model.load_state_dict(ckpt["model"], strict=False)

# counts & memory
n_params = sum(p.numel() for p in model.parameters())
def human(b): 
    return f"{b/1024/1024:.2f} MB" if b < 1024**3 else f"{b/1024/1024/1024:.2f} GB"
model_mem = n_params * 2           # bf16/fp16 weights ~2 bytes each
opt_states_same = n_params * 2 * 2 # two moments at same dtype
opt_states_fp32 = n_params * 2 * 4 # conservative fp32 optimizer states

print("Model args:", model_args)
print(f"Total parameters: {n_params:,}")
print("Model weights (fp16/bf16):", human(model_mem))
print("Optimizer states (same):  ", human(opt_states_same))
print("Optimizer states (fp32):  ", human(opt_states_fp32))
print("Total optimistic:", human(model_mem + opt_states_same))
print("Total conservative:", human(model_mem + opt_states_fp32))
# Out:
# number of parameters: 10.65M
# Model args: {'n_layer': 6, 'n_head': 4, 'n_embd': 384, 'block_size': 128, 'bias': False, 'vocab_size': 65, 'dropout': 0.1}
# Total parameters: 10,695,936
# Model weights (fp16/bf16): 20.40 MB
# Optimizer states (same):   40.80 MB
# Optimizer states (fp32):   81.60 MB
# Total optimistic: 61.20 MB
# Total conservative: 102.00 MB

# %%
# === Cell 8a: ensure checkpoint exists (create one quickly if missing) ===
import os, json, time, shlex
from pathlib import Path

repo = Path(REPO_DIR)
out_dir = Path(OUT_DIR)
ckpt = out_dir / "ckpt.pt"

if ckpt.exists():
    print("✅ Found checkpoint:", ckpt)
else:
    print("ℹ️ No checkpoint found at", ckpt)
    # Temporarily write a minimal override that forces an immediate eval+save and exits.
    temp_cfg = {
        "out_dir": str(out_dir),
        "data_dir": str(Path(DATA_DIR)),
        "eval_only": True,
        "always_save_checkpoint": True,
        # keep a tiny model so it's quick if the repo insists on building the net
        "block_size": 128, "n_layer": 2, "n_head": 2, "n_embd": 128,
        "batch_size": 8, "eval_iters": 10, "compile": False
    }
    tmp_override = out_dir / "config_override.json"
    tmp_override.write_text(json.dumps(temp_cfg, indent=2))
    print("Wrote temporary override →", tmp_override)

    # Run a one-off eval to save ckpt.pt
    cwd = os.getcwd()
    os.chdir(str(repo))
    ret = os.system("python train.py")
    os.chdir(cwd)

    if ckpt.exists():
        print("✅ Created checkpoint:", ckpt)
    else:
        raise SystemExit("❌ Could not create a checkpoint. Run training a bit (lower eval_interval) and retry.")
# Out:
# ✅ Found checkpoint: /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/out_onegroup/ckpt.pt

# %%
# === Cell 8b (safe): direct sampler with clamped top-k ===
import os, pickle, torch, time, importlib.util
from pathlib import Path

repo = Path(REPO_DIR)
out_dir = Path(OUT_DIR)
data_dir = Path(DATA_DIR)
ckpt_path = out_dir / "ckpt.pt"
meta_path = data_dir / "meta.pkl"
assert ckpt_path.exists(), f"Checkpoint not found: {ckpt_path}"
assert meta_path.exists(), f"meta.pkl not found: {meta_path}"

with open(meta_path, "rb") as f:
    meta = pickle.load(f)
stoi, itos = meta["stoi"], meta["itos"]

def encode(s): return [stoi[c] for c in s if c in stoi]
def decode(ids): return "".join(itos[i] for i in ids)

spec = importlib.util.spec_from_file_location("nanogpt_model", str(repo / "model.py"))
mod  = importlib.util.module_from_spec(spec); spec.loader.exec_module(mod)

ckpt = torch.load(str(ckpt_path), map_location="cpu")
model_args = ckpt.get("model_args") or ckpt.get("config") or {}
model = mod.GPT(mod.GPTConfig(**model_args))
model.load_state_dict(ckpt["model"], strict=False)
model.eval()

PROMPT = "In a quiet lab, the scientists examined the EEG signals and"
TEMPERATURE = 0.9
TOP_K = 80                 # will be clamped safely
MAX_NEW_TOKENS = 220

def top_k_logits(logits, k):
    if not k or k <= 0:
        return logits
    k = min(k, logits.size(-1))         # clamp to vocab size
    v, ix = torch.topk(logits, k, dim=-1)
    out = torch.full_like(logits, float("-inf"))
    out.scatter_(dim=-1, index=ix, src=v)
    return out

block_size = model.config.block_size
device = "cuda" if torch.cuda.is_available() else "cpu"
model.to(device)

ctx = torch.tensor([encode(PROMPT)], dtype=torch.long, device=device)
if ctx.size(1) == 0:
    ctx = torch.tensor([[stoi.get("\n", 0)]], dtype=torch.long, device=device)

generated = ctx.clone()
with torch.no_grad():
    for _ in range(MAX_NEW_TOKENS):
        idx_cond = generated[:, -block_size:]
        logits, _ = model(idx_cond)
        logits = logits[:, -1, :] / max(TEMPERATURE, 1e-6)
        logits = top_k_logits(logits, TOP_K)
        probs = torch.softmax(logits, dim=-1)
        next_id = torch.multinomial(probs, num_samples=1)
        generated = torch.cat([generated, next_id], dim=1)

text = decode(generated[0].tolist())
stamp = time.strftime("%Y%m%d-%H%M%S")
out_file = out_dir / f"sample_direct_T{TEMPERATURE}_K{TOP_K}_{stamp}.txt"
out_file.write_text(text, encoding="utf-8")
print("✅ Wrote sample →", out_file)
print("\n--- Preview ---\n")
print(text[:1000], "...\n")
# Out:
# number of parameters: 10.65M
# ✅ Wrote sample → /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/out_onegroup/sample_direct_T0.9_K80_20251028-182936.txt
#
# --- Preview ---
#
# In a quiet lab, the scientists examined the EEG signals and of there.
# Have thy stand this day, live your father of lets
# Tell but with you seem to wrong. For My lay the gentle!
#
# QUEEN MARGARET:
# They shall heart by and of my small as chuar be
# Thou tongue hearts sover flance how no ...

# %%
# === Cell 9: qualitative rubric & quick checklist ===
from pathlib import Path

rubric_text = """Qualitative Evaluation (score 1–5; add short notes)

1) Generated text quality & coherence: _____
   Note:
2) Long-range dependencies (≈100+ token consistency): _____
   Note:
3) Grammatical correctness: _____
   Note:
4) Style consistency with training data: _____
   Note:

Additional observations:
- Repetitions / loops:
- Contradictions:
- Topic drift:
- Strengths:
- Failure cases:
"""

rubric_path = Path(OUT_DIR) / "QUAL_RUBRIC.txt"
rubric_path.write_text(rubric_text, encoding="utf-8")
print("Rubric written →", rubric_path)

# Optional: preview the most recent generated sample
candidates = sorted(Path(OUT_DIR).glob("sample_direct_*.txt")) or sorted(Path(OUT_DIR).glob("sample_*.txt"))
if candidates:
    latest = candidates[-1]
    print("\n--- Latest sample preview:", latest.name, "---\n")
    print(latest.read_text(encoding="utf-8")[:1200], "...\n")
else:
    print("No sample file found yet. Run your sampling cell first (Cell 8).")
# Out:
# Rubric written → /home/STUDENTS/mc1836/projects/torch/Group 2/nanoGPT/out_onegroup/QUAL_RUBRIC.txt
#
# --- Latest sample preview: sample_direct_T0.9_K80_20251028-182936.txt ---
#
# In a quiet lab, the scientists examined the EEG signals and of there.
# Have thy stand this day, live your father of lets
# Tell but with you seem to wrong. For My lay the gentle!
#
# QUEEN MARGARET:
# They shall heart by and of my small as chuar be
# Thou tongue hearts sover flance how no ...
